# %%
import torch
import torchvision
import torch.nn as nn
import time
import json
import datetime
from DeepLearning.Project1.data import *

# %%
# File based on https://github.com/huyvnphan/PyTorch_CIFAR10/
class VGG(nn.Module):
    def __init__(self, features, num_classes=10, avgpool_size=(1,1)):
        super(VGG, self).__init__()
        self.features = features

        self.avgpool = nn.AdaptiveAvgPool2d(avgpool_size)

        self.classifier = nn.Sequential(
            nn.Linear(512 * avgpool_size[0] * avgpool_size[1], 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

 # Create convolution part of VGG11_bn archhitecture
def make_vgg11_bn_layers(cfg = None):
    if cfg == None:
        cfg = [64, "M", 128, "M", 256, 256, "M", 512, 512, "M", 512, 512, "M"]
    layers = []
    in_channels = 3
    for v in cfg:
        if v == "M":
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

 # Create VGG11_bn model
def vgg11_bn(device="cpu", num_classes=10):
    model = VGG(make_vgg11_bn_layers(), num_classes=num_classes)
    return model

vgg_cfg = {
    '8':  [64, 'M', 128, 'M', 256, 'M', 512, 'M', 512, 'M'],
    '11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    '13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    '16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    '19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 
          512, 512, 512, 512, 'M'],
}



def eval_accuracy(model, dataloader, training_device='cpu'):
    with torch.no_grad():
        model.to(training_device)
        correct = 0
        all_so_far = 0
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(training_device), labels.to(training_device)
            pred = torch.argmax(model(inputs), dim=1)

            all_so_far += labels.size().numel()
            correct += torch.sum(pred.eq(labels)).item()
    return correct/all_so_far

# %%
def backup_to_ram(model):
    from copy import deepcopy
    return deepcopy(model).cpu()

class EarlyStopper:
    def __init__(self, patience = 3, backup_method=backup_to_ram):
        self.patience = patience
        self.current = 0
        
        self.backup_method = backup_method
        
        self.best_backup = None
        self.best_accuracy = 0.

    def should_continue(self, accuracy, model = None):
        if self.best_accuracy < accuracy:
            self.current = 0
            self.best_accuracy = accuracy
            if model is not None:
                self.best_backup = self.backup_method(model)
            return True
        
        self.current += 1
        
        if self.current >= self.patience:
            return False
        return True

# %%
def train_one_epoch(model, optimizer, criterion, dataloader_train, training_device):
    for inputs, labels in dataloader_train:
        inputs, labels = inputs.to(training_device), labels.to(training_device)
        optimizer.zero_grad()
        loss = criterion(model(inputs), labels)
        loss.backward()
        optimizer.step()

def train_one_run(model, optimizer, criterion, dataloader_train, dataloader_val, max_epochs, early_stopper, trajectory, training_device='cuda', *_args, **_kwargs):
    model.train()
    model.to(training_device)
    for epoch in range(max_epochs):
        start_time = time.time()
        
        train_one_epoch(model, optimizer, criterion, dataloader_train, training_device)
        
        end_time = time.time()
        
        training_accuracy = eval_accuracy(model, dataloader_train, training_device)
        validation_accuracy = eval_accuracy(model, dataloader_val, training_device)
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "train": training_accuracy,
            "validation": validation_accuracy,
            "start_time": start_time,
            "duration": end_time - start_time,
            "memory_allocated_mb": torch.cuda.memory_allocated()/1024/1024,
            "memory_reserved_mb": torch.cuda.memory_reserved()/1024/1024,
        })
        
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            return early_stopper.best_backup
    
    return model

# %%
def run_aug_experiment(arch_name, model_factory, aug_name, aug_factory, run):
    path = "experiments/aug_" + aug_name + "_arch" + arch_name + "_" + run + "_"
    
    # 
    import os
    try:
        if os.stat(path + "report.json").st_size != 0:
            print("Report exists already for " + path[:-1] + ". Skipping...")
            return
    except OSError:
        pass
    
    train, test, val = aug_factory()
    print("data loaded")
    model = model_factory()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    early_stopper = EarlyStopper(patience = 5)
    trajectory = []
    print("experiment initialized")
    model = train_one_run(model, optimizer, criterion, train, val, 200, early_stopper, trajectory)
    validation_accuracy = eval_accuracy(model, val, "cuda")
    
    with open(path + "report.json", "w") as f:
        json.dump(
            {
                "name": arch_name,
                "run": run,
                "best_accuracy_validation": validation_accuracy,
                "time_generated": datetime.datetime.now().isoformat(),
                "trajectory": trajectory
            },
            f
        )
    torch.save(model, path + "model.pt")

# %%
def vgg_from_cfg(cfg_key):
    return VGG(
        make_vgg11_bn_layers(cfg=vgg_cfg[cfg_key]),
        num_classes=10,
        avgpool_size=(1,1)
    ).to("cuda")

def vgg11():
    return vgg_from_cfg("11")

def vgg13():
    return vgg_from_cfg("13")

def vgg16():
    return vgg_from_cfg("16")

# %%
def flip():
    return augmented_cifar10_dataset_randomflip(bs=128)

def small_rotate():
    return augmented_cifar10_dataset_randomrotate(5, bs=128)

def medium_rotate():
    return augmented_cifar10_dataset_randomrotate(45, bs=128)

def full_rotate():
    return augmented_cifar10_dataset_randomrotate(180, bs=128)

def fliprotate():
    return augmented_cifar10_dataset_randomflip_rotate(5, bs=128)

def noise():
    return augmented_cifar10_dataset_gauss_noise(0.05, bs=128)

def cutout():
    return augmented_cifar10_dataset_cutout(5, bs=128)

# %%
experiment_list = [
    (archfactory.__name__, archfactory, augfactory.__name__, augfactory, str(run))
    for run in range(1, 11)
    for archfactory in [vgg13, vgg16]
    for augfactory in [cutout]
]

# %%
for experiment in experiment_list:
    print(
        "Time:", datetime.datetime.now().isoformat(), 
        "Arch: ", experiment[0], 
        "Aug: ", experiment[2],
        "Run: ", experiment[4]
    )
    run_aug_experiment(*experiment)
# Out:
# Time: 2023-03-25T14:10:46.231156 Arch:  vgg13 Aug:  cutout Run:  1
# Report exists already for experiments/aug_cutout_archvgg13_1. Skipping...
# Time: 2023-03-25T14:10:46.232285 Arch:  vgg16 Aug:  cutout Run:  1
# Report exists already for experiments/aug_cutout_archvgg16_1. Skipping...
# Time: 2023-03-25T14:10:46.232458 Arch:  vgg13 Aug:  cutout Run:  2
# Report exists already for experiments/aug_cutout_archvgg13_2. Skipping...
# Time: 2023-03-25T14:10:46.233836 Arch:  vgg16 Aug:  cutout Run:  2
# Report exists already for experiments/aug_cutout_archvgg16_2. Skipping...
# Time: 2023-03-25T14:10:46.234007 Arch:  vgg13 Aug:  cutout Run:  3
# Report exists already for experiments/aug_cutout_archvgg13_3. Skipping...
# Time: 2023-03-25T14:10:46.234071 Arch:  vgg16 Aug:  cutout Run:  3
# Report exists already for experiments/aug_cutout_archvgg16_3. Skipping...
# Time: 2023-03-25T14:10:46.234176 Arch:  vgg13 Aug:  cutout Run:  4
# Report exists already for experiments/aug_cutout_archvgg13_4. Skipping...
# Time: 2023-03-25T14:10:46.234297 Arch:  vgg16 Aug:  cutout Run:  4
# Report exists already for experiments/aug_cutout_archvgg16_4. Skipping...
# Time: 2023-03-25T14:10:46.234378 Arch:  vgg13 Aug:  cutout Run:  5
# Report exists already for experiments/aug_cutout_archvgg13_5. Skipping...
# Time: 2023-03-25T14:10:46.234492 Arch:  vgg16 Aug:  cutout Run:  5
# Report exists already for experiments/aug_cutout_archvgg16_5. Skipping...
# Time: 2023-03-25T14:10:46.234553 Arch:  vgg13 Aug:  cutout Run:  6
# Report exists already for experiments/aug_cutout_archvgg13_6. Skipping...
# Time: 2023-03-25T14:10:46.234631 Arch:  vgg16 Aug:  cutout Run:  6
# Report exists already for experiments/aug_cutout_archvgg16_6. Skipping...
# Time: 2023-03-25T14:10:46.234718 Arch:  vgg13 Aug:  cutout Run:  7
# Report exists already for experiments/aug_cutout_archvgg13_7. Skipping...
# Time: 2023-03-25T14:10:46.234864 Arch:  vgg16 Aug:  cutout Run:  7
# Report exists already for experiments/aug_cutout_archvgg16_7. Skipping...
# Time: 2023-03-25T14:10:46.234991 Arch:  vgg13 Aug:  cutout Run:  8
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.3358
# Epoch: 1, Accuracy on validation set: 0.5176
# Epoch: 2, Accuracy on validation set: 0.6308
# Epoch: 3, Accuracy on validation set: 0.6984
# Epoch: 4, Accuracy on validation set: 0.7406
# Epoch: 5, Accuracy on validation set: 0.7662
# Epoch: 6, Accuracy on validation set: 0.7936
# Epoch: 7, Accuracy on validation set: 0.8044
# Epoch: 8, Accuracy on validation set: 0.8152
# Epoch: 9, Accuracy on validation set: 0.815
# Epoch: 10, Accuracy on validation set: 0.8252
# Epoch: 11, Accuracy on validation set: 0.825
# Epoch: 12, Accuracy on validation set: 0.8278
# Epoch: 13, Accuracy on validation set: 0.8356
# Epoch: 14, Accuracy on validation set: 0.8404
# Epoch: 15, Accuracy on validation set: 0.84
# Epoch: 16, Accuracy on validation set: 0.8354
# Epoch: 17, Accuracy on validation set: 0.8392
# Epoch: 18, Accuracy on validation set: 0.845
# Epoch: 19, Accuracy on validation set: 0.8494
# Epoch: 20, Accuracy on validation set: 0.8428
# Epoch: 21, Accuracy on validation set: 0.859
# Epoch: 22, Accuracy on validation set: 0.8514
# Epoch: 23, Accuracy on validation set: 0.857
# Epoch: 24, Accuracy on validation set: 0.8566
# Epoch: 25, Accuracy on validation set: 0.8598
# Epoch: 26, Accuracy on validation set: 0.856
# Epoch: 27, Accuracy on validation set: 0.8616
# Epoch: 28, Accuracy on validation set: 0.862
# Epoch: 29, Accuracy on validation set: 0.8574
# Epoch: 30, Accuracy on validation set: 0.8584
# Epoch: 31, Accuracy on validation set: 0.8542
# Epoch: 32, Accuracy on validation set: 0.8508
# Epoch: 33, Accuracy on validation set: 0.8632
# Epoch: 34, Accuracy on validation set: 0.863
# Epoch: 35, Accuracy on validation set: 0.8516
# Epoch: 36, Accuracy on validation set: 0.858
# Epoch: 37, Accuracy on validation set: 0.8654
# Epoch: 38, Accuracy on validation set: 0.8574
# Epoch: 39, Accuracy on validation set: 0.8604
# Epoch: 40, Accuracy on validation set: 0.858
# Epoch: 41, Accuracy on validation set: 0.8576
# Epoch: 42, Accuracy on validation set: 0.8648
# Early stop
# Time: 2023-03-25T14:31:14.451938 Arch:  vgg16 Aug:  cutout Run:  8
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.2026
# Epoch: 1, Accuracy on validation set: 0.3418
# Epoch: 2, Accuracy on validation set: 0.4186
# Epoch: 3, Accuracy on validation set: 0.5202
# Epoch: 4, Accuracy on validation set: 0.6164
# Epoch: 5, Accuracy on validation set: 0.6566
# Epoch: 6, Accuracy on validation set: 0.694
# Epoch: 7, Accuracy on validation set: 0.739
# Epoch: 8, Accuracy on validation set: 0.7616
# Epoch: 9, Accuracy on validation set: 0.7786
# Epoch: 10, Accuracy on validation set: 0.7974
# Epoch: 11, Accuracy on validation set: 0.8148
# Epoch: 12, Accuracy on validation set: 0.8212
# Epoch: 13, Accuracy on validation set: 0.8146
# Epoch: 14, Accuracy on validation set: 0.8274
# Epoch: 15, Accuracy on validation set: 0.825
# Epoch: 16, Accuracy on validation set: 0.8344
# Epoch: 17, Accuracy on validation set: 0.8384
# Epoch: 18, Accuracy on validation set: 0.8478
# Epoch: 19, Accuracy on validation set: 0.8392
# Epoch: 20, Accuracy on validation set: 0.8498
# Epoch: 21, Accuracy on validation set: 0.8432
# Epoch: 22, Accuracy on validation set: 0.8518
# Epoch: 23, Accuracy on validation set: 0.8514
# Epoch: 24, Accuracy on validation set: 0.8538
# Epoch: 25, Accuracy on validation set: 0.8238
# Epoch: 26, Accuracy on validation set: 0.8474
# Epoch: 27, Accuracy on validation set: 0.8548
# Epoch: 28, Accuracy on validation set: 0.856
# Epoch: 29, Accuracy on validation set: 0.8592
# Epoch: 30, Accuracy on validation set: 0.8478
# Epoch: 31, Accuracy on validation set: 0.8586
# Epoch: 32, Accuracy on validation set: 0.859
# Epoch: 33, Accuracy on validation set: 0.8606
# Epoch: 34, Accuracy on validation set: 0.8478
# Epoch: 35, Accuracy on validation set: 0.8562
# Epoch: 36, Accuracy on validation set: 0.8616
# Epoch: 37, Accuracy on validation set: 0.8646
# Epoch: 38, Accuracy on validation set: 0.855
# Epoch: 39, Accuracy on validation set: 0.857
# Epoch: 40, Accuracy on validation set: 0.8618
# Epoch: 41, Accuracy on validation set: 0.864
# Epoch: 42, Accuracy on validation set: 0.8602
# Early stop
# Time: 2023-03-25T14:52:55.194386 Arch:  vgg13 Aug:  cutout Run:  9
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.3122
# Epoch: 1, Accuracy on validation set: 0.4556
# Epoch: 2, Accuracy on validation set: 0.606
# Epoch: 3, Accuracy on validation set: 0.671
# Epoch: 4, Accuracy on validation set: 0.732
# Epoch: 5, Accuracy on validation set: 0.7526
# Epoch: 6, Accuracy on validation set: 0.774
# Epoch: 7, Accuracy on validation set: 0.7856
# Epoch: 8, Accuracy on validation set: 0.7994
# Epoch: 9, Accuracy on validation set: 0.8094
# Epoch: 10, Accuracy on validation set: 0.8208
# Epoch: 11, Accuracy on validation set: 0.8184
# Epoch: 12, Accuracy on validation set: 0.823
# Epoch: 13, Accuracy on validation set: 0.8304
# Epoch: 14, Accuracy on validation set: 0.839
# Epoch: 15, Accuracy on validation set: 0.8318
# Epoch: 16, Accuracy on validation set: 0.835
# Epoch: 17, Accuracy on validation set: 0.8358
# Epoch: 18, Accuracy on validation set: 0.8362
# Epoch: 19, Accuracy on validation set: 0.846
# Epoch: 20, Accuracy on validation set: 0.8484
# Epoch: 21, Accuracy on validation set: 0.8364
# Epoch: 22, Accuracy on validation set: 0.8478
# Epoch: 23, Accuracy on validation set: 0.8442
# Epoch: 24, Accuracy on validation set: 0.8458
# Epoch: 25, Accuracy on validation set: 0.8498
# Epoch: 26, Accuracy on validation set: 0.8534
# Epoch: 27, Accuracy on validation set: 0.8498
# Epoch: 28, Accuracy on validation set: 0.8526
# Epoch: 29, Accuracy on validation set: 0.8526
# Epoch: 30, Accuracy on validation set: 0.8538
# Epoch: 31, Accuracy on validation set: 0.8544
# Epoch: 32, Accuracy on validation set: 0.8526
# Epoch: 33, Accuracy on validation set: 0.8474
# Epoch: 34, Accuracy on validation set: 0.851
# Epoch: 35, Accuracy on validation set: 0.8568
# Epoch: 36, Accuracy on validation set: 0.8516
# Epoch: 37, Accuracy on validation set: 0.8504
# Epoch: 38, Accuracy on validation set: 0.8534
# Epoch: 39, Accuracy on validation set: 0.8522
# Epoch: 40, Accuracy on validation set: 0.8462
# Early stop
# Time: 2023-03-25T15:12:23.182483 Arch:  vgg16 Aug:  cutout Run:  9
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.2736
# Epoch: 1, Accuracy on validation set: 0.4128
# Epoch: 2, Accuracy on validation set: 0.5168
# Epoch: 3, Accuracy on validation set: 0.601
# Epoch: 4, Accuracy on validation set: 0.6516
# Epoch: 5, Accuracy on validation set: 0.709
# Epoch: 6, Accuracy on validation set: 0.7336
# Epoch: 7, Accuracy on validation set: 0.7658
# Epoch: 8, Accuracy on validation set: 0.7756
# Epoch: 9, Accuracy on validation set: 0.7922
# Epoch: 10, Accuracy on validation set: 0.799
# Epoch: 11, Accuracy on validation set: 0.8074
# Epoch: 12, Accuracy on validation set: 0.8202
# Epoch: 13, Accuracy on validation set: 0.8226
# Epoch: 14, Accuracy on validation set: 0.8326
# Epoch: 15, Accuracy on validation set: 0.832
# Epoch: 16, Accuracy on validation set: 0.838
# Epoch: 17, Accuracy on validation set: 0.8414
# Epoch: 18, Accuracy on validation set: 0.8452
# Epoch: 19, Accuracy on validation set: 0.84
# Epoch: 20, Accuracy on validation set: 0.8472
# Epoch: 21, Accuracy on validation set: 0.8458
# Epoch: 22, Accuracy on validation set: 0.8424
# Epoch: 23, Accuracy on validation set: 0.8468
# Epoch: 24, Accuracy on validation set: 0.847
# Epoch: 25, Accuracy on validation set: 0.8422
# Early stop
# Time: 2023-03-25T15:25:27.266684 Arch:  vgg13 Aug:  cutout Run:  10
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.3168
# Epoch: 1, Accuracy on validation set: 0.4222
# Epoch: 2, Accuracy on validation set: 0.5934
# Epoch: 3, Accuracy on validation set: 0.664
# Epoch: 4, Accuracy on validation set: 0.7098
# Epoch: 5, Accuracy on validation set: 0.7398
# Epoch: 6, Accuracy on validation set: 0.7602
# Epoch: 7, Accuracy on validation set: 0.7852
# Epoch: 8, Accuracy on validation set: 0.8026
# Epoch: 9, Accuracy on validation set: 0.8112
# Epoch: 10, Accuracy on validation set: 0.819
# Epoch: 11, Accuracy on validation set: 0.8278
# Epoch: 12, Accuracy on validation set: 0.8342
# Epoch: 13, Accuracy on validation set: 0.8346
# Epoch: 14, Accuracy on validation set: 0.8336
# Epoch: 15, Accuracy on validation set: 0.8372
# Epoch: 16, Accuracy on validation set: 0.8462
# Epoch: 17, Accuracy on validation set: 0.841
# Epoch: 18, Accuracy on validation set: 0.8444
# Epoch: 19, Accuracy on validation set: 0.8484
# Epoch: 20, Accuracy on validation set: 0.8464
# Epoch: 21, Accuracy on validation set: 0.8504
# Epoch: 22, Accuracy on validation set: 0.8474
# Epoch: 23, Accuracy on validation set: 0.847
# Epoch: 24, Accuracy on validation set: 0.851
# Epoch: 25, Accuracy on validation set: 0.85
# Epoch: 26, Accuracy on validation set: 0.8452
# Epoch: 27, Accuracy on validation set: 0.8444
# Epoch: 28, Accuracy on validation set: 0.852
# Epoch: 29, Accuracy on validation set: 0.845
# Epoch: 30, Accuracy on validation set: 0.8528
# Epoch: 31, Accuracy on validation set: 0.8492
# Epoch: 32, Accuracy on validation set: 0.85
# Epoch: 33, Accuracy on validation set: 0.8552
# Epoch: 34, Accuracy on validation set: 0.8462
# Epoch: 35, Accuracy on validation set: 0.8548
# Epoch: 36, Accuracy on validation set: 0.8456
# Epoch: 37, Accuracy on validation set: 0.8534
# Epoch: 38, Accuracy on validation set: 0.8554
# Epoch: 39, Accuracy on validation set: 0.8554
# Epoch: 40, Accuracy on validation set: 0.8522
# Epoch: 41, Accuracy on validation set: 0.8506
# Epoch: 42, Accuracy on validation set: 0.86
# Epoch: 43, Accuracy on validation set: 0.8554
# Epoch: 44, Accuracy on validation set: 0.855
# Epoch: 45, Accuracy on validation set: 0.8562
# Epoch: 46, Accuracy on validation set: 0.8552
# Epoch: 47, Accuracy on validation set: 0.8536
# Early stop
# Time: 2023-03-25T15:47:50.176048 Arch:  vgg16 Aug:  cutout Run:  10
# Files already downloaded and verified
# Files already downloaded and verified
# data loaded
# experiment initialized
# Epoch: 0, Accuracy on validation set: 0.2684
# Epoch: 1, Accuracy on validation set: 0.3976
# Epoch: 2, Accuracy on validation set: 0.4774
# Epoch: 3, Accuracy on validation set: 0.5872
# Epoch: 4, Accuracy on validation set: 0.6448
# Epoch: 5, Accuracy on validation set: 0.6948
# Epoch: 6, Accuracy on validation set: 0.7442
# Epoch: 7, Accuracy on validation set: 0.7644
# Epoch: 8, Accuracy on validation set: 0.7794
# Epoch: 9, Accuracy on validation set: 0.7934
# Epoch: 10, Accuracy on validation set: 0.805
# Epoch: 11, Accuracy on validation set: 0.8124
# Epoch: 12, Accuracy on validation set: 0.827
# Epoch: 13, Accuracy on validation set: 0.8198
# Epoch: 14, Accuracy on validation set: 0.8328
# Epoch: 15, Accuracy on validation set: 0.8382
# Epoch: 16, Accuracy on validation set: 0.8412
# Epoch: 17, Accuracy on validation set: 0.8422
# Epoch: 18, Accuracy on validation set: 0.834
# Epoch: 19, Accuracy on validation set: 0.8416
# Epoch: 20, Accuracy on validation set: 0.8418
# Epoch: 21, Accuracy on validation set: 0.8504
# Epoch: 22, Accuracy on validation set: 0.8486
# Epoch: 23, Accuracy on validation set: 0.8452
# Epoch: 24, Accuracy on validation set: 0.8464
# Epoch: 25, Accuracy on validation set: 0.856
# Epoch: 26, Accuracy on validation set: 0.8516
# Epoch: 27, Accuracy on validation set: 0.848
# Epoch: 28, Accuracy on validation set: 0.8484
# Epoch: 29, Accuracy on validation set: 0.8634
# Epoch: 30, Accuracy on validation set: 0.8598
# Epoch: 31, Accuracy on validation set: 0.856
# Epoch: 32, Accuracy on validation set: 0.8522
# Epoch: 33, Accuracy on validation set: 0.8634
# Epoch: 34, Accuracy on validation set: 0.8578
# Early stop

# %%
len(experiment_list)
