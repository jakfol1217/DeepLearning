# %%
import torch
import torchvision
import torch.nn as nn
import time
import json
import datetime


# Data loading and augmentation

def load_cifar10_dataloaders():
    transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    dataset_train = torchvision.datasets.CIFAR10(".data", download=True, transform=transform)
    dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=128)
    dataset_test = torchvision.datasets.CIFAR10(".data", download=True, train=False, transform=transform)
    dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=128)
    return dataloader_train, dataloader_test

def load_cifar10_dataloaders_validation():
    transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    dataset = torchvision.datasets.CIFAR10(".data", download=True, transform=transform)
    size_train = 0.9*len(dataset)
    size_val = len(dataset) - size_train
    dataset_train, dataset_val = torch.utils.data.random_split(dataset, [int(size_train), int(size_val)])
    dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=128)
    dataloader_val = torch.utils.data.DataLoader(dataset_val, batch_size=128)
    dataset_test = torchvision.datasets.CIFAR10(".data", download=True, train=False, transform=transform)
    dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=128)
    return dataloader_train, dataloader_test, dataloader_val

# %%
# File based on https://github.com/huyvnphan/PyTorch_CIFAR10/
class VGG(nn.Module):
    def __init__(self, features, num_classes=10, avgpool_size=(1,1)):
        super(VGG, self).__init__()
        self.features = features

        self.avgpool = nn.AdaptiveAvgPool2d(avgpool_size)

        self.classifier = nn.Sequential(
            nn.Linear(512 * avgpool_size[0] * avgpool_size[1], 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

 # Create convolution part of VGG11_bn archhitecture
def make_vgg11_bn_layers(cfg = None):
    if cfg == None:
        cfg = [64, "M", 128, "M", 256, 256, "M", 512, 512, "M", 512, 512, "M"]
    layers = []
    in_channels = 3
    for v in cfg:
        if v == "M":
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

 # Create VGG11_bn model
def vgg11_bn(device="cpu", num_classes=10):
    model = VGG(make_vgg11_bn_layers(), num_classes=num_classes)
    return model


def eval_accuracy(model, dataloader, training_device='cpu'):
    with torch.no_grad():
        model.to(training_device)
        correct = 0
        all_so_far = 0
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(training_device), labels.to(training_device)
            pred = torch.argmax(model(inputs), dim=1)

            all_so_far += labels.size().numel()
            correct += torch.sum(pred.eq(labels)).item()
    return correct/all_so_far

# %%
def backup_to_ram(model):
    from copy import deepcopy
    return deepcopy(model).cpu()

class EarlyStopper:
    def __init__(self, patience = 3, backup_method=backup_to_ram):
        self.patience = patience
        self.current = 0
        
        self.backup_method = backup_method
        
        self.best_backup = None
        self.best_accuracy = 0.

    def should_continue(self, accuracy, model = None):
        if self.best_accuracy < accuracy:
            self.current = 0
            self.best_accuracy = accuracy
            if model is not None:
                self.best_backup = self.backup_method(model)
            return True
        
        self.current += 1
        
        if self.current >= self.patience:
            return False
        return True

# %%
def train_one_epoch(model, optimizer, criterion, dataloader_train, training_device):
    for inputs, labels in dataloader_train:
        inputs, labels = inputs.to(training_device), labels.to(training_device)
        optimizer.zero_grad()
        loss = criterion(model(inputs), labels)
        loss.backward()
        optimizer.step()

def train_one_run(model, optimizer, criterion, dataloader_train, dataloader_val, max_epochs, early_stopper, trajectory, training_device='cuda', *_args, **_kwargs):
    model.train()
    model.to(training_device)

    for epoch in range(max_epochs):
        start_time = time.time()
        
        train_one_epoch(model, optimizer, criterion, dataloader_train, training_device)
        
        end_time = time.time()
        
        training_accuracy = eval_accuracy(model, dataloader_train, training_device)
        validation_accuracy = eval_accuracy(model, dataloader_val, training_device)
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "train": training_accuracy,
            "validation": validation_accuracy,
            "start_time": start_time,
            "duration": end_time - start_time,
            "memory_allocated_mb": torch.cuda.memory_allocated()/1024/1024,
            "memory_reserved_mb": torch.cuda.memory_reserved()/1024/1024,
        })
        
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            return early_stopper.best_backup
    
    return model

# %%
def run_arch_experiment(arch_name, model_factory, run):
    path = "experiments/arch/" + arch_name + "/" + run + "/"
    
    import os
    try:
        os.makedirs(path)
    except FileExistsError:
        print("Directory exists, skipping...")
        return
    
    train, test, val = load_cifar10_dataloaders_validation()
    model = model_factory()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    early_stopper = EarlyStopper(patience = 5)
    trajectory = []
    model = train_one_run(model, optimizer, criterion, train, val, 200, early_stopper, trajectory)
    validation_accuracy = eval_accuracy(model, val, "cuda")
    
    with open(path + "report.json", "w") as f:
        json.dump(
            {
                "name": arch_name,
                "run": run,
                "best_accuracy_validation": validation_accuracy,
                "time_generated": datetime.datetime.now().isoformat(),
                "trajectory": trajectory
            },
            f
        )
    torch.save(model, path + "model.pt")

# %%
def small_vgg11():
    return VGG(make_vgg11_bn_layers(), num_classes=10, avgpool_size=(1,1)).to("cuda")

def medium_vgg11():
    return VGG(make_vgg11_bn_layers(), num_classes=10, avgpool_size=(2,2)).to("cuda")

def full_vgg11():
    return VGG(make_vgg11_bn_layers(), num_classes=10, avgpool_size=(7,7)).to("cuda")

# %%
experiment_list = [
    (factory.__name__, factory, str(run))
    for factory in [small_vgg11, medium_vgg11, full_vgg11]
    for run in range(1, 11)
]

# %%
for experiment in experiment_list:
    print(
        "Time:", datetime.datetime.now().isoformat(), 
        "Arch: ", experiment[0], 
        "Run: ", experiment[2]
    )
    run_arch_experiment(*experiment)
# Out:
# Time: 2023-03-13T22:41:04.364512 Arch:  small_vgg11 Run:  1
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365353 Arch:  small_vgg11 Run:  2
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365409 Arch:  small_vgg11 Run:  3
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365440 Arch:  small_vgg11 Run:  4
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365491 Arch:  small_vgg11 Run:  5
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365522 Arch:  small_vgg11 Run:  6
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365552 Arch:  small_vgg11 Run:  7
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365720 Arch:  small_vgg11 Run:  8
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365759 Arch:  small_vgg11 Run:  9
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365789 Arch:  small_vgg11 Run:  10
# Directory exists, skipping...
# Time: 2023-03-13T22:41:04.365837 Arch:  medium_vgg11 Run:  1
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.207
# Epoch: 1, Accuracy on validation set: 0.3616
# Epoch: 2, Accuracy on validation set: 0.4604
# Epoch: 3, Accuracy on validation set: 0.5494
# Epoch: 4, Accuracy on validation set: 0.6284
# Epoch: 5, Accuracy on validation set: 0.682
# Epoch: 6, Accuracy on validation set: 0.7204
# Epoch: 7, Accuracy on validation set: 0.7368
# Epoch: 8, Accuracy on validation set: 0.7546
# Epoch: 9, Accuracy on validation set: 0.7824
# Epoch: 10, Accuracy on validation set: 0.7922
# Epoch: 11, Accuracy on validation set: 0.7902
# Epoch: 12, Accuracy on validation set: 0.798
# Epoch: 13, Accuracy on validation set: 0.8
# Epoch: 14, Accuracy on validation set: 0.803
# Epoch: 15, Accuracy on validation set: 0.8006
# Epoch: 16, Accuracy on validation set: 0.7952
# Epoch: 17, Accuracy on validation set: 0.8072
# Epoch: 18, Accuracy on validation set: 0.8108
# Epoch: 19, Accuracy on validation set: 0.811
# Epoch: 20, Accuracy on validation set: 0.8126
# Epoch: 21, Accuracy on validation set: 0.8036
# Epoch: 22, Accuracy on validation set: 0.8218
# Epoch: 23, Accuracy on validation set: 0.8208
# Epoch: 24, Accuracy on validation set: 0.809
# Epoch: 25, Accuracy on validation set: 0.8156
# Epoch: 26, Accuracy on validation set: 0.814
# Epoch: 27, Accuracy on validation set: 0.8184
# Early stop
# Time: 2023-03-13T22:50:12.837779 Arch:  medium_vgg11 Run:  2
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2684
# Epoch: 1, Accuracy on validation set: 0.392
# Epoch: 2, Accuracy on validation set: 0.5466
# Epoch: 3, Accuracy on validation set: 0.6262
# Epoch: 4, Accuracy on validation set: 0.6838
# Epoch: 5, Accuracy on validation set: 0.7178
# Epoch: 6, Accuracy on validation set: 0.7346
# Epoch: 7, Accuracy on validation set: 0.7534
# Epoch: 8, Accuracy on validation set: 0.772
# Epoch: 9, Accuracy on validation set: 0.762
# Epoch: 10, Accuracy on validation set: 0.7756
# Epoch: 11, Accuracy on validation set: 0.7904
# Epoch: 12, Accuracy on validation set: 0.788
# Epoch: 13, Accuracy on validation set: 0.8018
# Epoch: 14, Accuracy on validation set: 0.8046
# Epoch: 15, Accuracy on validation set: 0.798
# Epoch: 16, Accuracy on validation set: 0.8132
# Epoch: 17, Accuracy on validation set: 0.8006
# Epoch: 18, Accuracy on validation set: 0.8116
# Epoch: 19, Accuracy on validation set: 0.8118
# Epoch: 20, Accuracy on validation set: 0.8202
# Epoch: 21, Accuracy on validation set: 0.8192
# Epoch: 22, Accuracy on validation set: 0.8178
# Epoch: 23, Accuracy on validation set: 0.8152
# Epoch: 24, Accuracy on validation set: 0.8258
# Epoch: 25, Accuracy on validation set: 0.8164
# Epoch: 26, Accuracy on validation set: 0.8254
# Epoch: 27, Accuracy on validation set: 0.818
# Epoch: 28, Accuracy on validation set: 0.8172
# Epoch: 29, Accuracy on validation set: 0.8238
# Early stop
# Time: 2023-03-13T23:00:02.618150 Arch:  medium_vgg11 Run:  3
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.262
# Epoch: 1, Accuracy on validation set: 0.3862
# Epoch: 2, Accuracy on validation set: 0.4576
# Epoch: 3, Accuracy on validation set: 0.6038
# Epoch: 4, Accuracy on validation set: 0.6572
# Epoch: 5, Accuracy on validation set: 0.6888
# Epoch: 6, Accuracy on validation set: 0.7166
# Epoch: 7, Accuracy on validation set: 0.7406
# Epoch: 8, Accuracy on validation set: 0.7564
# Epoch: 9, Accuracy on validation set: 0.7688
# Epoch: 10, Accuracy on validation set: 0.7872
# Epoch: 11, Accuracy on validation set: 0.8004
# Epoch: 12, Accuracy on validation set: 0.7992
# Epoch: 13, Accuracy on validation set: 0.8084
# Epoch: 14, Accuracy on validation set: 0.8056
# Epoch: 15, Accuracy on validation set: 0.805
# Epoch: 16, Accuracy on validation set: 0.8068
# Epoch: 17, Accuracy on validation set: 0.817
# Epoch: 18, Accuracy on validation set: 0.8168
# Epoch: 19, Accuracy on validation set: 0.8092
# Epoch: 20, Accuracy on validation set: 0.8136
# Epoch: 21, Accuracy on validation set: 0.8122
# Epoch: 22, Accuracy on validation set: 0.816
# Early stop
# Time: 2023-03-13T23:07:34.343038 Arch:  medium_vgg11 Run:  4
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2596
# Epoch: 1, Accuracy on validation set: 0.3776
# Epoch: 2, Accuracy on validation set: 0.5426
# Epoch: 3, Accuracy on validation set: 0.642
# Epoch: 4, Accuracy on validation set: 0.6936
# Epoch: 5, Accuracy on validation set: 0.7284
# Epoch: 6, Accuracy on validation set: 0.7466
# Epoch: 7, Accuracy on validation set: 0.7662
# Epoch: 8, Accuracy on validation set: 0.774
# Epoch: 9, Accuracy on validation set: 0.7782
# Epoch: 10, Accuracy on validation set: 0.7824
# Epoch: 11, Accuracy on validation set: 0.7816
# Epoch: 12, Accuracy on validation set: 0.785
# Epoch: 13, Accuracy on validation set: 0.8008
# Epoch: 14, Accuracy on validation set: 0.8004
# Epoch: 15, Accuracy on validation set: 0.7976
# Epoch: 16, Accuracy on validation set: 0.8122
# Epoch: 17, Accuracy on validation set: 0.8106
# Epoch: 18, Accuracy on validation set: 0.8082
# Epoch: 19, Accuracy on validation set: 0.818
# Epoch: 20, Accuracy on validation set: 0.8194
# Epoch: 21, Accuracy on validation set: 0.8084
# Epoch: 22, Accuracy on validation set: 0.814
# Epoch: 23, Accuracy on validation set: 0.7834
# Epoch: 24, Accuracy on validation set: 0.8146
# Epoch: 25, Accuracy on validation set: 0.816
# Early stop
# Time: 2023-03-13T23:16:15.090617 Arch:  medium_vgg11 Run:  5
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.258
# Epoch: 1, Accuracy on validation set: 0.4128
# Epoch: 2, Accuracy on validation set: 0.5464
# Epoch: 3, Accuracy on validation set: 0.6478
# Epoch: 4, Accuracy on validation set: 0.6994
# Epoch: 5, Accuracy on validation set: 0.731
# Epoch: 6, Accuracy on validation set: 0.7454
# Epoch: 7, Accuracy on validation set: 0.7668
# Epoch: 8, Accuracy on validation set: 0.7694
# Epoch: 9, Accuracy on validation set: 0.7802
# Epoch: 10, Accuracy on validation set: 0.7836
# Epoch: 11, Accuracy on validation set: 0.7916
# Epoch: 12, Accuracy on validation set: 0.7934
# Epoch: 13, Accuracy on validation set: 0.7942
# Epoch: 14, Accuracy on validation set: 0.7948
# Epoch: 15, Accuracy on validation set: 0.8074
# Epoch: 16, Accuracy on validation set: 0.8052
# Epoch: 17, Accuracy on validation set: 0.8118
# Epoch: 18, Accuracy on validation set: 0.8144
# Epoch: 19, Accuracy on validation set: 0.8194
# Epoch: 20, Accuracy on validation set: 0.8182
# Epoch: 21, Accuracy on validation set: 0.8142
# Epoch: 22, Accuracy on validation set: 0.8168
# Epoch: 23, Accuracy on validation set: 0.8208
# Epoch: 24, Accuracy on validation set: 0.82
# Epoch: 25, Accuracy on validation set: 0.823
# Epoch: 26, Accuracy on validation set: 0.8302
# Epoch: 27, Accuracy on validation set: 0.8252
# Epoch: 28, Accuracy on validation set: 0.8214
# Epoch: 29, Accuracy on validation set: 0.8164
# Epoch: 30, Accuracy on validation set: 0.8242
# Epoch: 31, Accuracy on validation set: 0.824
# Early stop
# Time: 2023-03-13T23:26:36.444561 Arch:  medium_vgg11 Run:  6
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2562
# Epoch: 1, Accuracy on validation set: 0.3556
# Epoch: 2, Accuracy on validation set: 0.4504
# Epoch: 3, Accuracy on validation set: 0.5394
# Epoch: 4, Accuracy on validation set: 0.622
# Epoch: 5, Accuracy on validation set: 0.7082
# Epoch: 6, Accuracy on validation set: 0.7272
# Epoch: 7, Accuracy on validation set: 0.7522
# Epoch: 8, Accuracy on validation set: 0.7562
# Epoch: 9, Accuracy on validation set: 0.7766
# Epoch: 10, Accuracy on validation set: 0.7708
# Epoch: 11, Accuracy on validation set: 0.7848
# Epoch: 12, Accuracy on validation set: 0.7934
# Epoch: 13, Accuracy on validation set: 0.7784
# Epoch: 14, Accuracy on validation set: 0.7892
# Epoch: 15, Accuracy on validation set: 0.7856
# Epoch: 16, Accuracy on validation set: 0.794
# Epoch: 17, Accuracy on validation set: 0.8022
# Epoch: 18, Accuracy on validation set: 0.8034
# Epoch: 19, Accuracy on validation set: 0.8018
# Epoch: 20, Accuracy on validation set: 0.81
# Epoch: 21, Accuracy on validation set: 0.7996
# Epoch: 22, Accuracy on validation set: 0.8104
# Epoch: 23, Accuracy on validation set: 0.8056
# Epoch: 24, Accuracy on validation set: 0.811
# Epoch: 25, Accuracy on validation set: 0.8022
# Epoch: 26, Accuracy on validation set: 0.8046
# Epoch: 27, Accuracy on validation set: 0.815
# Epoch: 28, Accuracy on validation set: 0.8064
# Epoch: 29, Accuracy on validation set: 0.8062
# Epoch: 30, Accuracy on validation set: 0.8106
# Epoch: 31, Accuracy on validation set: 0.8192
# Epoch: 32, Accuracy on validation set: 0.8098
# Epoch: 33, Accuracy on validation set: 0.8034
# Epoch: 34, Accuracy on validation set: 0.7976
# Epoch: 35, Accuracy on validation set: 0.8058
# Epoch: 36, Accuracy on validation set: 0.7948
# Early stop
# Time: 2023-03-13T23:38:43.325496 Arch:  medium_vgg11 Run:  7
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2576
# Epoch: 1, Accuracy on validation set: 0.3686
# Epoch: 2, Accuracy on validation set: 0.467
# Epoch: 3, Accuracy on validation set: 0.5286
# Epoch: 4, Accuracy on validation set: 0.628
# Epoch: 5, Accuracy on validation set: 0.673
# Epoch: 6, Accuracy on validation set: 0.7136
# Epoch: 7, Accuracy on validation set: 0.7302
# Epoch: 8, Accuracy on validation set: 0.7428
# Epoch: 9, Accuracy on validation set: 0.7664
# Epoch: 10, Accuracy on validation set: 0.7648
# Epoch: 11, Accuracy on validation set: 0.7766
# Epoch: 12, Accuracy on validation set: 0.7824
# Epoch: 13, Accuracy on validation set: 0.7874
# Epoch: 14, Accuracy on validation set: 0.7834
# Epoch: 15, Accuracy on validation set: 0.794
# Epoch: 16, Accuracy on validation set: 0.7938
# Epoch: 17, Accuracy on validation set: 0.7998
# Epoch: 18, Accuracy on validation set: 0.798
# Epoch: 19, Accuracy on validation set: 0.8014
# Epoch: 20, Accuracy on validation set: 0.8036
# Epoch: 21, Accuracy on validation set: 0.7922
# Epoch: 22, Accuracy on validation set: 0.8096
# Epoch: 23, Accuracy on validation set: 0.8062
# Epoch: 24, Accuracy on validation set: 0.8066
# Epoch: 25, Accuracy on validation set: 0.8136
# Epoch: 26, Accuracy on validation set: 0.8098
# Epoch: 27, Accuracy on validation set: 0.8128
# Epoch: 28, Accuracy on validation set: 0.8134
# Epoch: 29, Accuracy on validation set: 0.8152
# Epoch: 30, Accuracy on validation set: 0.8158
# Epoch: 31, Accuracy on validation set: 0.8014
# Epoch: 32, Accuracy on validation set: 0.7986
# Epoch: 33, Accuracy on validation set: 0.8158
# Epoch: 34, Accuracy on validation set: 0.8
# Epoch: 35, Accuracy on validation set: 0.8064
# Early stop
# Time: 2023-03-13T23:50:30.879849 Arch:  medium_vgg11 Run:  8
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2514
# Epoch: 1, Accuracy on validation set: 0.3686
# Epoch: 2, Accuracy on validation set: 0.4914
# Epoch: 3, Accuracy on validation set: 0.588
# Epoch: 4, Accuracy on validation set: 0.6716
# Epoch: 5, Accuracy on validation set: 0.7166
# Epoch: 6, Accuracy on validation set: 0.7284
# Epoch: 7, Accuracy on validation set: 0.7442
# Epoch: 8, Accuracy on validation set: 0.7614
# Epoch: 9, Accuracy on validation set: 0.7618
# Epoch: 10, Accuracy on validation set: 0.7864
# Epoch: 11, Accuracy on validation set: 0.787
# Epoch: 12, Accuracy on validation set: 0.789
# Epoch: 13, Accuracy on validation set: 0.7998
# Epoch: 14, Accuracy on validation set: 0.8032
# Epoch: 15, Accuracy on validation set: 0.8102
# Epoch: 16, Accuracy on validation set: 0.8074
# Epoch: 17, Accuracy on validation set: 0.8114
# Epoch: 18, Accuracy on validation set: 0.8082
# Epoch: 19, Accuracy on validation set: 0.8142
# Epoch: 20, Accuracy on validation set: 0.8196
# Epoch: 21, Accuracy on validation set: 0.7886
# Epoch: 22, Accuracy on validation set: 0.8236
# Epoch: 23, Accuracy on validation set: 0.8138
# Epoch: 24, Accuracy on validation set: 0.8138
# Epoch: 25, Accuracy on validation set: 0.8268
# Epoch: 26, Accuracy on validation set: 0.811
# Epoch: 27, Accuracy on validation set: 0.8222
# Epoch: 28, Accuracy on validation set: 0.8098
# Epoch: 29, Accuracy on validation set: 0.8106
# Epoch: 30, Accuracy on validation set: 0.8274
# Epoch: 31, Accuracy on validation set: 0.8292
# Epoch: 32, Accuracy on validation set: 0.8232
# Epoch: 33, Accuracy on validation set: 0.835
# Epoch: 34, Accuracy on validation set: 0.8224
# Epoch: 35, Accuracy on validation set: 0.825
# Epoch: 36, Accuracy on validation set: 0.8202
# Epoch: 37, Accuracy on validation set: 0.8288
# Epoch: 38, Accuracy on validation set: 0.8236
# Early stop
# Time: 2023-03-14T00:03:03.604833 Arch:  medium_vgg11 Run:  9
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.2484
# Epoch: 1, Accuracy on validation set: 0.3728
# Epoch: 2, Accuracy on validation set: 0.4914
# Epoch: 3, Accuracy on validation set: 0.6032
# Epoch: 4, Accuracy on validation set: 0.6544
# Epoch: 5, Accuracy on validation set: 0.697
# Epoch: 6, Accuracy on validation set: 0.7142
# Epoch: 7, Accuracy on validation set: 0.738
# Epoch: 8, Accuracy on validation set: 0.7538
# Epoch: 9, Accuracy on validation set: 0.764
# Epoch: 10, Accuracy on validation set: 0.7788
# Epoch: 11, Accuracy on validation set: 0.769
# Epoch: 12, Accuracy on validation set: 0.7834
# Epoch: 13, Accuracy on validation set: 0.7838
# Epoch: 14, Accuracy on validation set: 0.7944
# Epoch: 15, Accuracy on validation set: 0.7962
# Epoch: 16, Accuracy on validation set: 0.7974
# Epoch: 17, Accuracy on validation set: 0.7932
# Epoch: 18, Accuracy on validation set: 0.8032
# Epoch: 19, Accuracy on validation set: 0.8012
# Epoch: 20, Accuracy on validation set: 0.756
# Epoch: 21, Accuracy on validation set: 0.8104
# Epoch: 22, Accuracy on validation set: 0.8048
# Epoch: 23, Accuracy on validation set: 0.8046
# Epoch: 24, Accuracy on validation set: 0.8226
# Epoch: 25, Accuracy on validation set: 0.8106
# Epoch: 26, Accuracy on validation set: 0.8116
# Epoch: 27, Accuracy on validation set: 0.8096
# Epoch: 28, Accuracy on validation set: 0.813
# Epoch: 29, Accuracy on validation set: 0.807
# Early stop
# Time: 2023-03-14T00:12:46.662442 Arch:  medium_vgg11 Run:  10
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.197
# Epoch: 1, Accuracy on validation set: 0.3438
# Epoch: 2, Accuracy on validation set: 0.403
# Epoch: 3, Accuracy on validation set: 0.5256
# Epoch: 4, Accuracy on validation set: 0.6134
# Epoch: 5, Accuracy on validation set: 0.6498
# Epoch: 6, Accuracy on validation set: 0.7014
# Epoch: 7, Accuracy on validation set: 0.7368
# Epoch: 8, Accuracy on validation set: 0.7598
# Epoch: 9, Accuracy on validation set: 0.7622
# Epoch: 10, Accuracy on validation set: 0.7792
# Epoch: 11, Accuracy on validation set: 0.7832
# Epoch: 12, Accuracy on validation set: 0.7732
# Epoch: 13, Accuracy on validation set: 0.7812
# Epoch: 14, Accuracy on validation set: 0.8012
# Epoch: 15, Accuracy on validation set: 0.8054
# Epoch: 16, Accuracy on validation set: 0.807
# Epoch: 17, Accuracy on validation set: 0.8036
# Epoch: 18, Accuracy on validation set: 0.802
# Epoch: 19, Accuracy on validation set: 0.79
# Epoch: 20, Accuracy on validation set: 0.8026
# Epoch: 21, Accuracy on validation set: 0.7992
# Early stop
# Time: 2023-03-14T00:20:08.056690 Arch:  full_vgg11 Run:  1
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1576
# Epoch: 1, Accuracy on validation set: 0.152
# Epoch: 2, Accuracy on validation set: 0.1732
# Epoch: 3, Accuracy on validation set: 0.1786
# Epoch: 4, Accuracy on validation set: 0.2088
# Epoch: 5, Accuracy on validation set: 0.2092
# Epoch: 6, Accuracy on validation set: 0.223
# Epoch: 7, Accuracy on validation set: 0.2208
# Epoch: 8, Accuracy on validation set: 0.241
# Epoch: 9, Accuracy on validation set: 0.235
# Epoch: 10, Accuracy on validation set: 0.2376
# Epoch: 11, Accuracy on validation set: 0.2462
# Epoch: 12, Accuracy on validation set: 0.2376
# Epoch: 13, Accuracy on validation set: 0.2568
# Epoch: 14, Accuracy on validation set: 0.2594
# Epoch: 15, Accuracy on validation set: 0.2706
# Epoch: 16, Accuracy on validation set: 0.279
# Epoch: 17, Accuracy on validation set: 0.3022
# Epoch: 18, Accuracy on validation set: 0.3548
# Epoch: 19, Accuracy on validation set: 0.3734
# Epoch: 20, Accuracy on validation set: 0.4148
# Epoch: 21, Accuracy on validation set: 0.5806
# Epoch: 22, Accuracy on validation set: 0.6588
# Epoch: 23, Accuracy on validation set: 0.7008
# Epoch: 24, Accuracy on validation set: 0.7158
# Epoch: 25, Accuracy on validation set: 0.7432
# Epoch: 26, Accuracy on validation set: 0.7566
# Epoch: 27, Accuracy on validation set: 0.7564
# Epoch: 28, Accuracy on validation set: 0.7706
# Epoch: 29, Accuracy on validation set: 0.7684
# Epoch: 30, Accuracy on validation set: 0.768
# Epoch: 31, Accuracy on validation set: 0.7754
# Epoch: 32, Accuracy on validation set: 0.784
# Epoch: 33, Accuracy on validation set: 0.7846
# Epoch: 34, Accuracy on validation set: 0.7952
# Epoch: 35, Accuracy on validation set: 0.7884
# Epoch: 36, Accuracy on validation set: 0.7884
# Epoch: 37, Accuracy on validation set: 0.7862
# Epoch: 38, Accuracy on validation set: 0.7978
# Epoch: 39, Accuracy on validation set: 0.8008
# Epoch: 40, Accuracy on validation set: 0.799
# Epoch: 41, Accuracy on validation set: 0.8012
# Epoch: 42, Accuracy on validation set: 0.7938
# Epoch: 43, Accuracy on validation set: 0.7916
# Epoch: 44, Accuracy on validation set: 0.797
# Epoch: 45, Accuracy on validation set: 0.8012
# Epoch: 46, Accuracy on validation set: 0.8002
# Early stop
# Time: 2023-03-14T00:43:35.318256 Arch:  full_vgg11 Run:  2
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1474
# Epoch: 1, Accuracy on validation set: 0.1572
# Epoch: 2, Accuracy on validation set: 0.1602
# Epoch: 3, Accuracy on validation set: 0.169
# Epoch: 4, Accuracy on validation set: 0.18
# Epoch: 5, Accuracy on validation set: 0.172
# Epoch: 6, Accuracy on validation set: 0.1692
# Epoch: 7, Accuracy on validation set: 0.1846
# Epoch: 8, Accuracy on validation set: 0.1956
# Epoch: 9, Accuracy on validation set: 0.2174
# Epoch: 10, Accuracy on validation set: 0.2078
# Epoch: 11, Accuracy on validation set: 0.2004
# Epoch: 12, Accuracy on validation set: 0.2724
# Epoch: 13, Accuracy on validation set: 0.3974
# Epoch: 14, Accuracy on validation set: 0.4446
# Epoch: 15, Accuracy on validation set: 0.5124
# Epoch: 16, Accuracy on validation set: 0.4354
# Epoch: 17, Accuracy on validation set: 0.5978
# Epoch: 18, Accuracy on validation set: 0.6244
# Epoch: 19, Accuracy on validation set: 0.6252
# Epoch: 20, Accuracy on validation set: 0.6522
# Epoch: 21, Accuracy on validation set: 0.5458
# Epoch: 22, Accuracy on validation set: 0.6752
# Epoch: 23, Accuracy on validation set: 0.695
# Epoch: 24, Accuracy on validation set: 0.7202
# Epoch: 25, Accuracy on validation set: 0.7358
# Epoch: 26, Accuracy on validation set: 0.7238
# Epoch: 27, Accuracy on validation set: 0.6684
# Epoch: 28, Accuracy on validation set: 0.7352
# Epoch: 29, Accuracy on validation set: 0.7428
# Epoch: 30, Accuracy on validation set: 0.7436
# Epoch: 31, Accuracy on validation set: 0.7588
# Epoch: 32, Accuracy on validation set: 0.7508
# Epoch: 33, Accuracy on validation set: 0.7458
# Epoch: 34, Accuracy on validation set: 0.7518
# Epoch: 35, Accuracy on validation set: 0.7626
# Epoch: 36, Accuracy on validation set: 0.7592
# Epoch: 37, Accuracy on validation set: 0.7736
# Epoch: 38, Accuracy on validation set: 0.7698
# Epoch: 39, Accuracy on validation set: 0.7694
# Epoch: 40, Accuracy on validation set: 0.7636
# Epoch: 41, Accuracy on validation set: 0.7602
# Epoch: 42, Accuracy on validation set: 0.7792
# Epoch: 43, Accuracy on validation set: 0.7786
# Epoch: 44, Accuracy on validation set: 0.7838
# Epoch: 45, Accuracy on validation set: 0.783
# Epoch: 46, Accuracy on validation set: 0.7618
# Epoch: 47, Accuracy on validation set: 0.7848
# Epoch: 48, Accuracy on validation set: 0.7676
# Epoch: 49, Accuracy on validation set: 0.7696
# Epoch: 50, Accuracy on validation set: 0.7888
# Epoch: 51, Accuracy on validation set: 0.796
# Epoch: 52, Accuracy on validation set: 0.7908
# Epoch: 53, Accuracy on validation set: 0.7818
# Epoch: 54, Accuracy on validation set: 0.7876
# Epoch: 55, Accuracy on validation set: 0.7616
# Epoch: 56, Accuracy on validation set: 0.7822
# Early stop
# Time: 2023-03-14T01:11:57.223635 Arch:  full_vgg11 Run:  3
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1632
# Epoch: 1, Accuracy on validation set: 0.1708
# Epoch: 2, Accuracy on validation set: 0.1774
# Epoch: 3, Accuracy on validation set: 0.1656
# Epoch: 4, Accuracy on validation set: 0.1802
# Epoch: 5, Accuracy on validation set: 0.1772
# Epoch: 6, Accuracy on validation set: 0.188
# Epoch: 7, Accuracy on validation set: 0.2052
# Epoch: 8, Accuracy on validation set: 0.2336
# Epoch: 9, Accuracy on validation set: 0.2302
# Epoch: 10, Accuracy on validation set: 0.2466
# Epoch: 11, Accuracy on validation set: 0.3914
# Epoch: 12, Accuracy on validation set: 0.4456
# Epoch: 13, Accuracy on validation set: 0.5028
# Epoch: 14, Accuracy on validation set: 0.5928
# Epoch: 15, Accuracy on validation set: 0.6526
# Epoch: 16, Accuracy on validation set: 0.6786
# Epoch: 17, Accuracy on validation set: 0.6982
# Epoch: 18, Accuracy on validation set: 0.7278
# Epoch: 19, Accuracy on validation set: 0.7058
# Epoch: 20, Accuracy on validation set: 0.7288
# Epoch: 21, Accuracy on validation set: 0.66
# Epoch: 22, Accuracy on validation set: 0.7502
# Epoch: 23, Accuracy on validation set: 0.737
# Epoch: 24, Accuracy on validation set: 0.7368
# Epoch: 25, Accuracy on validation set: 0.7414
# Epoch: 26, Accuracy on validation set: 0.759
# Epoch: 27, Accuracy on validation set: 0.7546
# Epoch: 28, Accuracy on validation set: 0.7678
# Epoch: 29, Accuracy on validation set: 0.781
# Epoch: 30, Accuracy on validation set: 0.7816
# Epoch: 31, Accuracy on validation set: 0.7628
# Epoch: 32, Accuracy on validation set: 0.78
# Epoch: 33, Accuracy on validation set: 0.7706
# Epoch: 34, Accuracy on validation set: 0.594
# Epoch: 35, Accuracy on validation set: 0.7616
# Early stop
# Time: 2023-03-14T01:29:52.943137 Arch:  full_vgg11 Run:  4
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.153
# Epoch: 1, Accuracy on validation set: 0.1674
# Epoch: 2, Accuracy on validation set: 0.172
# Epoch: 3, Accuracy on validation set: 0.1694
# Epoch: 4, Accuracy on validation set: 0.1786
# Epoch: 5, Accuracy on validation set: 0.1794
# Epoch: 6, Accuracy on validation set: 0.233
# Epoch: 7, Accuracy on validation set: 0.3112
# Epoch: 8, Accuracy on validation set: 0.3426
# Epoch: 9, Accuracy on validation set: 0.4036
# Epoch: 10, Accuracy on validation set: 0.446
# Epoch: 11, Accuracy on validation set: 0.5468
# Epoch: 12, Accuracy on validation set: 0.584
# Epoch: 13, Accuracy on validation set: 0.6224
# Epoch: 14, Accuracy on validation set: 0.6602
# Epoch: 15, Accuracy on validation set: 0.6774
# Epoch: 16, Accuracy on validation set: 0.698
# Epoch: 17, Accuracy on validation set: 0.6998
# Epoch: 18, Accuracy on validation set: 0.7196
# Epoch: 19, Accuracy on validation set: 0.725
# Epoch: 20, Accuracy on validation set: 0.7404
# Epoch: 21, Accuracy on validation set: 0.7222
# Epoch: 22, Accuracy on validation set: 0.7504
# Epoch: 23, Accuracy on validation set: 0.7516
# Epoch: 24, Accuracy on validation set: 0.7586
# Epoch: 25, Accuracy on validation set: 0.7524
# Epoch: 26, Accuracy on validation set: 0.7654
# Epoch: 27, Accuracy on validation set: 0.7598
# Epoch: 28, Accuracy on validation set: 0.7606
# Epoch: 29, Accuracy on validation set: 0.6946
# Epoch: 30, Accuracy on validation set: 0.7448
# Epoch: 31, Accuracy on validation set: 0.7686
# Epoch: 32, Accuracy on validation set: 0.7718
# Epoch: 33, Accuracy on validation set: 0.745
# Epoch: 34, Accuracy on validation set: 0.7668
# Epoch: 35, Accuracy on validation set: 0.7624
# Epoch: 36, Accuracy on validation set: 0.7562
# Epoch: 37, Accuracy on validation set: 0.7642
# Early stop
# Time: 2023-03-14T01:48:49.697168 Arch:  full_vgg11 Run:  5
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1624
# Epoch: 1, Accuracy on validation set: 0.186
# Epoch: 2, Accuracy on validation set: 0.1868
# Epoch: 3, Accuracy on validation set: 0.1978
# Epoch: 4, Accuracy on validation set: 0.2694
# Epoch: 5, Accuracy on validation set: 0.2586
# Epoch: 6, Accuracy on validation set: 0.3452
# Epoch: 7, Accuracy on validation set: 0.3762
# Epoch: 8, Accuracy on validation set: 0.3282
# Epoch: 9, Accuracy on validation set: 0.5018
# Epoch: 10, Accuracy on validation set: 0.519
# Epoch: 11, Accuracy on validation set: 0.6308
# Epoch: 12, Accuracy on validation set: 0.6706
# Epoch: 13, Accuracy on validation set: 0.6332
# Epoch: 14, Accuracy on validation set: 0.6486
# Epoch: 15, Accuracy on validation set: 0.6848
# Epoch: 16, Accuracy on validation set: 0.702
# Epoch: 17, Accuracy on validation set: 0.6916
# Epoch: 18, Accuracy on validation set: 0.7274
# Epoch: 19, Accuracy on validation set: 0.7398
# Epoch: 20, Accuracy on validation set: 0.735
# Epoch: 21, Accuracy on validation set: 0.7342
# Epoch: 22, Accuracy on validation set: 0.7524
# Epoch: 23, Accuracy on validation set: 0.7348
# Epoch: 24, Accuracy on validation set: 0.7276
# Epoch: 25, Accuracy on validation set: 0.749
# Epoch: 26, Accuracy on validation set: 0.754
# Epoch: 27, Accuracy on validation set: 0.692
# Epoch: 28, Accuracy on validation set: 0.756
# Epoch: 29, Accuracy on validation set: 0.7408
# Epoch: 30, Accuracy on validation set: 0.7516
# Epoch: 31, Accuracy on validation set: 0.723
# Epoch: 32, Accuracy on validation set: 0.754
# Epoch: 33, Accuracy on validation set: 0.6602
# Early stop
# Time: 2023-03-14T02:05:45.646059 Arch:  full_vgg11 Run:  6
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1092
# Epoch: 1, Accuracy on validation set: 0.1002
# Epoch: 2, Accuracy on validation set: 0.101
# Epoch: 3, Accuracy on validation set: 0.1022
# Epoch: 4, Accuracy on validation set: 0.0968
# Epoch: 5, Accuracy on validation set: 0.1018
# Early stop
# Time: 2023-03-14T02:08:46.200420 Arch:  full_vgg11 Run:  7
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1572
# Epoch: 1, Accuracy on validation set: 0.1652
# Epoch: 2, Accuracy on validation set: 0.1738
# Epoch: 3, Accuracy on validation set: 0.1728
# Epoch: 4, Accuracy on validation set: 0.1824
# Epoch: 5, Accuracy on validation set: 0.1746
# Epoch: 6, Accuracy on validation set: 0.1922
# Epoch: 7, Accuracy on validation set: 0.1948
# Epoch: 8, Accuracy on validation set: 0.1976
# Epoch: 9, Accuracy on validation set: 0.1938
# Epoch: 10, Accuracy on validation set: 0.2122
# Epoch: 11, Accuracy on validation set: 0.2298
# Epoch: 12, Accuracy on validation set: 0.25
# Epoch: 13, Accuracy on validation set: 0.2716
# Epoch: 14, Accuracy on validation set: 0.2556
# Epoch: 15, Accuracy on validation set: 0.2996
# Epoch: 16, Accuracy on validation set: 0.2996
# Epoch: 17, Accuracy on validation set: 0.3216
# Epoch: 18, Accuracy on validation set: 0.3496
# Epoch: 19, Accuracy on validation set: 0.3622
# Epoch: 20, Accuracy on validation set: 0.3926
# Epoch: 21, Accuracy on validation set: 0.4352
# Epoch: 22, Accuracy on validation set: 0.5046
# Epoch: 23, Accuracy on validation set: 0.543
# Epoch: 24, Accuracy on validation set: 0.6134
# Epoch: 25, Accuracy on validation set: 0.6598
# Epoch: 26, Accuracy on validation set: 0.6938
# Epoch: 27, Accuracy on validation set: 0.7174
# Epoch: 28, Accuracy on validation set: 0.7316
# Epoch: 29, Accuracy on validation set: 0.7386
# Epoch: 30, Accuracy on validation set: 0.7396
# Epoch: 31, Accuracy on validation set: 0.7516
# Epoch: 32, Accuracy on validation set: 0.753
# Epoch: 33, Accuracy on validation set: 0.7612
# Epoch: 34, Accuracy on validation set: 0.7538
# Epoch: 35, Accuracy on validation set: 0.7688
# Epoch: 36, Accuracy on validation set: 0.783
# Epoch: 37, Accuracy on validation set: 0.7722
# Epoch: 38, Accuracy on validation set: 0.7728
# Epoch: 39, Accuracy on validation set: 0.7894
# Epoch: 40, Accuracy on validation set: 0.786
# Epoch: 41, Accuracy on validation set: 0.784
# Epoch: 42, Accuracy on validation set: 0.781
# Epoch: 43, Accuracy on validation set: 0.7846
# Epoch: 44, Accuracy on validation set: 0.8042
# Epoch: 45, Accuracy on validation set: 0.8032
# Epoch: 46, Accuracy on validation set: 0.7892
# Epoch: 47, Accuracy on validation set: 0.7942
# Epoch: 48, Accuracy on validation set: 0.7888
# Epoch: 49, Accuracy on validation set: 0.7958
# Early stop
# Time: 2023-03-14T02:33:44.811488 Arch:  full_vgg11 Run:  8
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1748
# Epoch: 1, Accuracy on validation set: 0.175
# Epoch: 2, Accuracy on validation set: 0.189
# Epoch: 3, Accuracy on validation set: 0.207
# Epoch: 4, Accuracy on validation set: 0.2688
# Epoch: 5, Accuracy on validation set: 0.3118
# Epoch: 6, Accuracy on validation set: 0.3626
# Epoch: 7, Accuracy on validation set: 0.4202
# Epoch: 8, Accuracy on validation set: 0.4766
# Epoch: 9, Accuracy on validation set: 0.5306
# Epoch: 10, Accuracy on validation set: 0.5148
# Epoch: 11, Accuracy on validation set: 0.5718
# Epoch: 12, Accuracy on validation set: 0.6252
# Epoch: 13, Accuracy on validation set: 0.6406
# Epoch: 14, Accuracy on validation set: 0.6154
# Epoch: 15, Accuracy on validation set: 0.6712
# Epoch: 16, Accuracy on validation set: 0.6706
# Epoch: 17, Accuracy on validation set: 0.6298
# Epoch: 18, Accuracy on validation set: 0.689
# Epoch: 19, Accuracy on validation set: 0.7184
# Epoch: 20, Accuracy on validation set: 0.6864
# Epoch: 21, Accuracy on validation set: 0.6812
# Epoch: 22, Accuracy on validation set: 0.717
# Epoch: 23, Accuracy on validation set: 0.739
# Epoch: 24, Accuracy on validation set: 0.7438
# Epoch: 25, Accuracy on validation set: 0.7472
# Epoch: 26, Accuracy on validation set: 0.7512
# Epoch: 27, Accuracy on validation set: 0.7464
# Epoch: 28, Accuracy on validation set: 0.7192
# Epoch: 29, Accuracy on validation set: 0.7574
# Epoch: 30, Accuracy on validation set: 0.761
# Epoch: 31, Accuracy on validation set: 0.7294
# Epoch: 32, Accuracy on validation set: 0.7764
# Epoch: 33, Accuracy on validation set: 0.7688
# Epoch: 34, Accuracy on validation set: 0.7676
# Epoch: 35, Accuracy on validation set: 0.7836
# Epoch: 36, Accuracy on validation set: 0.7516
# Epoch: 37, Accuracy on validation set: 0.7734
# Epoch: 38, Accuracy on validation set: 0.7782
# Epoch: 39, Accuracy on validation set: 0.7818
# Epoch: 40, Accuracy on validation set: 0.783
# Early stop
# Time: 2023-03-14T02:54:08.307879 Arch:  full_vgg11 Run:  9
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1626
# Epoch: 1, Accuracy on validation set: 0.1754
# Epoch: 2, Accuracy on validation set: 0.1816
# Epoch: 3, Accuracy on validation set: 0.1934
# Epoch: 4, Accuracy on validation set: 0.1898
# Epoch: 5, Accuracy on validation set: 0.2322
# Epoch: 6, Accuracy on validation set: 0.297
# Epoch: 7, Accuracy on validation set: 0.3818
# Epoch: 8, Accuracy on validation set: 0.4478
# Epoch: 9, Accuracy on validation set: 0.3916
# Epoch: 10, Accuracy on validation set: 0.5538
# Epoch: 11, Accuracy on validation set: 0.5704
# Epoch: 12, Accuracy on validation set: 0.4322
# Epoch: 13, Accuracy on validation set: 0.5874
# Epoch: 14, Accuracy on validation set: 0.6498
# Epoch: 15, Accuracy on validation set: 0.6552
# Epoch: 16, Accuracy on validation set: 0.6832
# Epoch: 17, Accuracy on validation set: 0.7104
# Epoch: 18, Accuracy on validation set: 0.7176
# Epoch: 19, Accuracy on validation set: 0.6954
# Epoch: 20, Accuracy on validation set: 0.724
# Epoch: 21, Accuracy on validation set: 0.715
# Epoch: 22, Accuracy on validation set: 0.726
# Epoch: 23, Accuracy on validation set: 0.7578
# Epoch: 24, Accuracy on validation set: 0.7544
# Epoch: 25, Accuracy on validation set: 0.7518
# Epoch: 26, Accuracy on validation set: 0.7686
# Epoch: 27, Accuracy on validation set: 0.7698
# Epoch: 28, Accuracy on validation set: 0.7592
# Epoch: 29, Accuracy on validation set: 0.7754
# Epoch: 30, Accuracy on validation set: 0.7372
# Epoch: 31, Accuracy on validation set: 0.771
# Epoch: 32, Accuracy on validation set: 0.7658
# Epoch: 33, Accuracy on validation set: 0.7604
# Epoch: 34, Accuracy on validation set: 0.7618
# Early stop
# Time: 2023-03-14T03:11:34.822278 Arch:  full_vgg11 Run:  10
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 0, Accuracy on validation set: 0.1416
# Epoch: 1, Accuracy on validation set: 0.135
# Epoch: 2, Accuracy on validation set: 0.148
# Epoch: 3, Accuracy on validation set: 0.1344
# Epoch: 4, Accuracy on validation set: 0.1338
# Epoch: 5, Accuracy on validation set: 0.1428
# Epoch: 6, Accuracy on validation set: 0.1564
# Epoch: 7, Accuracy on validation set: 0.1554
# Epoch: 8, Accuracy on validation set: 0.1628
# Epoch: 9, Accuracy on validation set: 0.155
# Epoch: 10, Accuracy on validation set: 0.1902
# Epoch: 11, Accuracy on validation set: 0.1662
# Epoch: 12, Accuracy on validation set: 0.2824
# Epoch: 13, Accuracy on validation set: 0.3774
# Epoch: 14, Accuracy on validation set: 0.486
# Epoch: 15, Accuracy on validation set: 0.5686
# Epoch: 16, Accuracy on validation set: 0.6388
# Epoch: 17, Accuracy on validation set: 0.673
# Epoch: 18, Accuracy on validation set: 0.6618
# Epoch: 19, Accuracy on validation set: 0.637
# Epoch: 20, Accuracy on validation set: 0.7222
# Epoch: 21, Accuracy on validation set: 0.6864
# Epoch: 22, Accuracy on validation set: 0.7178
# Epoch: 23, Accuracy on validation set: 0.7484
# Epoch: 24, Accuracy on validation set: 0.7396
# Epoch: 25, Accuracy on validation set: 0.4666
# Epoch: 26, Accuracy on validation set: 0.733
# Epoch: 27, Accuracy on validation set: 0.7464
# Epoch: 28, Accuracy on validation set: 0.7438
# Early stop
