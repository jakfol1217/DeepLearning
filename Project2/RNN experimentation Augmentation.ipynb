# %%
import torch
import torchvision
import torch.nn as nn
import time
import json
import datetime
import matplotlib.pyplot as plt

# %%
# %cd
from DeepLearning.Project2.data_loading_preparation import *
# Out:
# /home/kacper

# %%
def get_generic_classifier(input_size, hidden_size, output_size):
    classifier = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_size, output_size),
    )
    return classifier
    
class LSTMSimple(nn.Module):
    def __init__(
        self,
        input_size, 
        hidden_size,
        num_layers,
        num_classes = 12,
        avgpool_dim = 32,
        classifier_size = 512,
        add_dropout=True
    ):       
        super().__init__()
        self.normalization = nn.BatchNorm1d(input_size)
        self.features = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.avgpool = nn.AdaptiveAvgPool1d(avgpool_dim)
        self.classifier = get_generic_classifier(
            hidden_size * avgpool_dim,
            classifier_size,
            num_classes
        )

    def forward(self, x):
        x = self.normalization(x)
        x = x.mT
        x, _ = self.features(x)
        x = x.mT
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def eval_accuracy(model, dataloader, reccurrent, training_device='cuda'):
    with torch.no_grad():
        model.to(training_device)
        correct = 0
        all_so_far = 0
        for inputs, labels in dataloader:
            inputs, labels = inputs.float().to(training_device), labels.float().to(training_device)
            yhat = model(inputs)
            pred = torch.argmax(yhat, dim=1)

            
            all_so_far += labels.size().numel()
            correct += torch.sum(pred.eq(labels)).item()
    return correct/all_so_far

# %%
def backup_to_ram(model):
    from copy import deepcopy
    return deepcopy(model).cpu()

class EarlyStopper:
    def __init__(self, patience = 3, backup_method=backup_to_ram):
        self.patience = patience
        self.current = 0
        
        self.backup_method = backup_method
        
        self.best_backup = None
        self.best_accuracy = 0.

    def should_continue(self, accuracy, model = None):
        if self.best_accuracy < accuracy:
            self.current = 0
            self.best_accuracy = accuracy
            if model is not None:
                self.best_backup = self.backup_method(model)
            return True
        
        self.current += 1
        
        if self.current >= self.patience:
            return False
        return True

# %%
def run_experiment(experiment_name, train_func, run, train_params=None):
    path = f"experiments_rnn/{experiment_name}_run_{run}_"
    print("Running experiment for ", path[:-1])
    
    import os
    try:
        if os.stat(path + "report.json").st_size != 0:
            print("Report exists already for " + path[:-1] + ". Skipping...")
            return
    except OSError:
        pass
    
    model, trajectory, validation_accuracy = train_func(train_params)
    
    with open(path + "report.json", "w") as f:
        json.dump(
            {
                "name": experiment_name,
                "train_params": train_params,
                "run": run,
                "best_accuracy_validation": validation_accuracy,
                "time_generated": datetime.datetime.now().isoformat(),
                "trajectory": trajectory
            },
            f
        )
    torch.save(model, path + "model.pt")

# %%
training_device = "cuda"
device = "cuda"
max_epochs = 250

def noaugLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_validation(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timeshiftLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_timeshift(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def pitchshiftLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_pitchshift(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def speedshiftLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_speedshift(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timemaskLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_timemask(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy

def freqmaskLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_freqmask(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timeshiftfreqmaskLSTMdifferentiator(params):  
    train, test, val = load_audio_dataloaders_timeshift_freqmask(bs=128, limit_11=0.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.0]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy

# %%
param_grid = {
    "smallsingle": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 1,
    },
    "mediumsingle": {
        "hidden_size": 128,
        "input_size": 20,
        "num_layers": 1,
    },
    "smallsinglefatclassifier": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 1,
        "classifier_size": 1024
    },
    "smalldoublefatclassifier": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 2,
        "classifier_size": 1024
    },
    "mediumsinglefatclassifier": {
        "hidden_size": 128,
        "input_size": 20,
        "num_layers": 1,
        "classifier_size": 1024
    },
}


experiment_list = [
    (
        f"trainer_{trainer.__name__}_params_{param_name}", 
        trainer,
        str(run),
        param
    )
    for run in range(1, 11) 
    for trainer in [noaugLSTMdifferentiator, pitchshiftLSTMdifferentiator, speedshiftLSTMdifferentiator, timeshiftLSTMdifferentiator, timemaskLSTMdifferentiator, freqmaskLSTMdifferentiator, timeshiftfreqmaskLSTMdifferentiator]
    for param_name, param in param_grid.items()
]

# %%
len(experiment_list)
# Out:
# 350

# %%
for experiment in experiment_list:
    print(
        "Time:", datetime.datetime.now().isoformat(),
        "Experiment:", experiment[0]
    )
    try:
        run_experiment(*experiment)
    except Exception as e:
        print("Error occured, skipping...\n", repr(e))
# Out:
# Time: 2023-04-21T18:00:08.333797 Experiment: trainer_noaugLSTMdifferentiator_params_smallsingle
# Running experiment for  experiments_rnn/trainer_noaugLSTMdifferentiator_params_smallsingle_run_1
# Report exists already for experiments_rnn/trainer_noaugLSTMdifferentiator_params_smallsingle_run_1. Skipping...
# Time: 2023-04-21T18:00:08.
# Epoch: 76, Accuracy on validation set: 0.6883720930232559
# Epoch: 77, Accuracy on validation set: 0.6868217054263566
# Epoch: 78, Accuracy on validation set: 0.6918604651162791
# Epoch: 79, Accuracy on validation set: 0.6914728682170542
# Epoch: 80, Accuracy on validation set: 0.6732558139534883
# Epoch: 81, Accuracy on validation set: 0.7031007751937984
# Epoch: 82, Accuracy on validation set: 0.713953488372093
# Epoch: 83, Accuracy on validation set: 0.6604651162790698
# Epoch: 84, Accuracy on validation set: 0.7054263565891473
# Epoch: 85, Accuracy on validation set: 0.6976744186046512
# Epoch: 86, Accuracy on validation set: 0.7124031007751938
# Epoch: 87, Accuracy on validation set: 0.7073643410852714
# Epoch: 88, Accuracy on validation set: 0.6980620155038759
# Epoch: 89, Accuracy on validation set: 0.6961240310077519
# Epoch: 90, Accuracy on validation set: 0.7007751937984497
# Epoch: 91, Accuracy on validation set: 0.7077519379844961
# Epoch: 92, Accuracy on validation set: 0.7093023255813954
# Epoch: 93, Accuracy on validation set: 0.7093023255813954
# Epoch: 94, Accuracy on validation set: 0.6794573643410853
# Early stop
# Time: 2023-04-21T18:09:05.315637 Experiment: trainer_freqmaskLSTMdifferentiator_params_mediumsingle
# Running experiment for  experiments_rnn/trainer_freqmaskLSTMdifferentiator_params_mediumsingle_run_4
# Epoch: 1, Accuracy on validation set: 0.32325581395348835
# Epoch: 2, Accuracy on validation set: 0.4062015503875969
# Epoch: 3, Accuracy on validation set: 0.4821705426356589
# Epoch: 4, Accuracy on validation set: 0.5147286821705427
# Epoch: 5, Accuracy on validation set: 0.5352713178294574
# Epoch: 6, Accuracy on validation set: 0.5430232558139535
# Epoch: 7, Accuracy on validation set: 0.48372093023255813
# Epoch: 8, Accuracy on validation set: 0.562015503875969
# Epoch: 9, Accuracy on validation set: 0.6069767441860465
# Epoch: 10, Accuracy on validation set: 0.6127906976744186
# Epoch: 11, Accuracy on validation set: 0.5883720930232558
# Epoch: 12, Accuracy on validation set: 0.5903100775193798
# Epoch: 13, Accuracy on validation set: 0.6515503875968992
# Epoch: 14, Accuracy on validation set: 0.6604651162790698
# Epoch: 15, Accuracy on validation set: 0.6170542635658914
# Epoch: 16, Accuracy on validation set: 0.6348837209302326
# Epoch: 17, Accuracy on validation set: 0.5775193798449613
# Epoch: 18, Accuracy on validation set: 0.625968992248062
# Epoch: 19, Accuracy on validation set: 0.6709302325581395
# Epoch: 20, Accuracy on validation set: 0.6790697674418604
# Epoch: 21, Accuracy on validation set: 0.6565891472868217
# Epoch: 22, Accuracy on validation set: 0.6651162790697674
# Epoch: 23, Accuracy on validation set: 0.6724806201550387
# Epoch: 24, Accuracy on validation set: 0.6651162790697674
# Epoch: 25, Accuracy on validation set: 0.6705426356589147
# Epoch: 26, Accuracy on validation set: 0.6356589147286822
# Epoch: 27, Accuracy on validation set: 0.6573643410852713
# Epoch: 28, Accuracy on validation set: 0.6631782945736434
# Epoch: 29, Accuracy on validation set: 0.6693798449612403
# Epoch: 30, Accuracy on validation set: 0.6895348837209302
# Epoch: 31, Accuracy on validation set: 0.674031007751938
# Epoch: 32, Accuracy on validation set: 0.624031007751938
# Epoch: 33, Accuracy on validation set: 0.6906976744186046
# Epoch: 34, Accuracy on validation set: 0.6608527131782945
# Epoch: 35, Accuracy on validation set: 0.6779069767441861
# Epoch: 36, Accuracy on validation set: 0.5945736434108527
# Epoch: 37, Accuracy on validation set: 0.639922480620155
# Epoch: 38, Accuracy on validation set: 0.6934108527131783
# Epoch: 39, Accuracy on validation set: 0.6744186046511628
# Epoch: 40, Accuracy on validation set: 0.672093023255814
# Epoch: 41, Accuracy on validation set: 0.6926356589147287
# Epoch: 42, Accuracy on validation set: 0.6887596899224806
# Epoch: 43, Accuracy on validation set: 0.6507751937984496
# Epoch: 44, Accuracy on validation set: 0.6717054263565891
# Epoch: 45, Accuracy on validation set: 0.6782945736434108
# Epoch: 46, Accuracy on validation set: 0.6282945736434109
# Epoch: 47, Accuracy on validation set: 0.6686046511627907
# Epoch: 48, Accuracy on validation set: 0.6496124031007752
# Epoch: 49, Accuracy on validation set: 0.6581395348837209
# Epoch: 50, Accuracy on validation set: 0.6546511627906977
# Epoch: 51, Accuracy on validation set: 0.663953488372093
# Epoch: 52, Accuracy on validation set: 0.6689922480620155
# Epoch: 53, Accuracy on validation set: 0.6573643410852713
# Epoch: 54, Accuracy on validation set: 0.622093023255814
# Epoch: 55, Accuracy on validation set: 0.6387596899224807
# Epoch: 56, Accuracy on validation set: 0.5988372093023255
# Epoch: 57, Accuracy on validation set: 0.637984496124031
# Epoch: 58, Accuracy on validation set: 0.6875968992248062
# Early stop
# Time: 2023-04-21T18:14:45.414868 Experiment: trainer_freqmaskLSTMdifferentiator_params_smallsinglefatclassifier
# Running experiment for  experiments_rnn/trainer_freqmaskLSTMdifferentiator_params_smallsinglefatclassifier_run_4
# Epoch: 1, Accuracy on validation set: 0.34806201550387594
# Epoch: 2, Accuracy on validation set: 0.41550387596899224
# Epoch: 3, Accuracy on validation set: 0.4248062015503876
# Epoch: 4, Accuracy on validation set: 0.4197674418604651
# Epoch: 5, Accuracy on validation set: 0.4414728682170543
# Epoch: 6, Accuracy on validation set: 0.49844961240310076
# Epoch: 7, Accuracy on validation set: 0.5112403100775194
# Epoch: 8, Accuracy on validation set: 0.5131782945736434
# Epoch: 9, Accuracy on validation set: 0.5143410852713178
# Epoch: 10, Accuracy on validation set: 0.5414728682170543
# Epoch: 11, Accuracy on validation set: 0.5426356589147286
# Epoch: 12, Accuracy on validation set: 0.5414728682170543
# Epoch: 13, Accuracy on validation set: 0.5713178294573643
# Epoch: 14, Accuracy on validation set: 0.5531007751937984
# Epoch: 15, Accuracy on validation set: 0.5817829457364341
# Epoch: 16, Accuracy on validation set: 0.5926356589147287
# Epoch: 17, Accuracy on validation set: 0.5709302325581396
# Epoch: 18, Accuracy on validation set: 0.5844961240310077
# Epoch: 19, Accuracy on validation set: 0.5864341085271317
# Epoch: 20, Accuracy on validation set: 0.5856589147286821
# Epoch: 21, Accuracy on validation set: 0.5837209302325581
# Epoch: 22, Accuracy on validation set: 0.6151162790697674
# Epoch: 23, Accuracy on validation set: 0.6085271317829457
# Epoch: 24, Accuracy on validation set: 0.6248062015503876
# Epoch: 25, Accuracy on validation set: 0.6096899224806202
# Epoch: 26, Accuracy on validation set: 0.6310077519379845
# Epoch: 27, Accuracy on validation set: 0.6089147286821706
# Epoch: 28, Accuracy on validation set: 0.6077519379844961
# Epoch: 29, Accuracy on validation set: 0.6062015503875969
# Epoch: 30, Accuracy on validation set: 0.5891472868217055
# Epoch: 31, Accuracy on validation set: 0.5957364341085272
# Epoch: 32, Accuracy on validation set: 0.6178294573643411
# Epoch: 33, Accuracy on validation set: 0.6054263565891473
# Epoch: 34, Accuracy on validation set: 0.6127906976744186
# Epoch: 35, Accuracy on validation set: 0.6294573643410852
# Epoch: 36, Accuracy on validation set: 0.6391472868217054
# Epoch: 37, Accuracy on validation set: 0.648062015503876
# Epoch: 38, Accuracy on validation set: 0.6069767441860465
# Epoch: 39, Accuracy on validation set: 0.6050387596899225
# Epoch: 40, Accuracy on validation set: 0.6422480620155039
# Epoch: 41, Accuracy on validation set: 0.6426356589147287
# Epoch: 42, Accuracy on validation set: 0.646124031007752
# Epoch: 43, Accuracy on validation set: 0.6267441860465116
# Epoch: 44, Accuracy on validation set: 0.624031007751938
# Epoch: 45, Accuracy on validation set: 0.6170542635658914
# Epoch: 46, Accuracy on validation set: 0.625968992248062
# Epoch: 47, Accuracy on validation set: 0.6007751937984496
# Epoch: 48, Accuracy on validation set: 0.6189922480620155
# Epoch: 49, Accuracy on validation set: 0.6360465116279069
# Epoch: 50, Accuracy on validation set: 0.6395348837209303
# Epoch: 51, Accuracy on validation set: 0.6015503875968993
# Epoch: 52, Accuracy on validation set: 0.5961240310077519
# Epoch: 53, Accuracy on validation set: 0.6147286821705427
# Epoch: 54, Accuracy on validation set: 0.6437984496124031
# Epoch: 55, Accuracy on validation set: 0.662015503875969
# Epoch: 56, Accuracy on validation set: 0.6263565891472869
# Epoch: 57, Accuracy on validation set: 0.6317829457364341
# Epoch: 58, Accuracy on validation set: 0.6143410852713178
# Epoch: 59, Accuracy on validation set: 0.6286821705426356
# Epoch: 60, Accuracy on validation set: 0.6116279069767442
# Epoch: 61, Accuracy on validation set: 0.6344961240310077
# Epoch: 62, Accuracy on validation set: 0.6197674418604651
# Epoch: 63, Accuracy on validation set: 0.6251937984496124
# Epoch: 64, Accuracy on validation set: 0.6635658914728683
# Epoch: 65, Accuracy on validation set: 0.6186046511627907
# Epoch: 66, Accuracy on validation set: 0.6271317829457365
# Epoch: 67, Accuracy on validation set: 0.6426356589147287
# Epoch: 68, Accuracy on validation set: 0.6565891472868217
# Epoch: 69, Accuracy on validation set: 0.6201550387596899
# Epoch: 70, Accuracy on validation set: 0.6286821705426356
# Epoch: 71, Accuracy on validation set: 0.65
# Epoch: 72, Accuracy on validation set: 0.6437984496124031
# Epoch: 73, Accuracy on validation set: 0.6434108527131783
# Epoch: 74, Accuracy on validation set: 0.6406976744186047
# Epoch: 75, Accuracy on validation set: 0.6558139534883721
# Epoch: 76, Accuracy on validation set: 0.6647286821705426
# Epoch: 77, Accuracy on validation set: 0.624031007751938
# Epoch: 78, Accuracy on validation set: 0.6232558139534884
# Epoch: 79, Accuracy on validation set: 0.6476744186046511
# Epoch: 80, Accuracy on validation set: 0.6503875968992248
# Epoch: 81, Accuracy on validation set: 0.6616279069767442
# Epoch: 82, Accuracy on validation set: 0.6410852713178294
# Epoch: 83, Accuracy on validation set: 0.6430232558139535
# Epoch: 84, Accuracy on validation set: 0.608139534883721
# Epoch: 85, Accuracy on validation set: 0.5996124031007752
# Epoch: 86, Accuracy on validation set: 0.6112403100775193
# Epoch: 87, Accuracy on validation set: 0.6112403100775193
# Epoch: 88, Accuracy on validation set: 0.6224806201550388
# Epoch: 89, Accuracy on validation set: 0.6356589147286822
# Epoch: 90, Accuracy on validation set: 0.6294573643410852
# Epoch: 91, Accuracy on validation set: 0.624031007751938
# Epoch: 92, Accuracy on validation set: 0.6302325581395349
# Epoch: 93, Accuracy on validation set: 0.5883720930232558
# Epoch: 94, Accuracy on validation set: 0.6352713178294573
# Epoch: 95, Accuracy on validation set: 0.6201550387596899
# Epoch: 96, Accuracy on validation set: 0.6178294573643411
# Early stop
# Time: 2023-04-21T18:23:49.612456 Experiment: trainer_freqmaskLSTMdifferentiator_params_smalldoublefatclassifier
# Running experiment for  experiments_rnn/trainer_freqmaskLSTMdifferentiator_params_smalldoublefatclassifier_run_4
# Epoch: 1, Accuracy on validation set: 0.28837209302325584
# Epoch: 2, Accuracy on validation set: 0.40271317829457365
# Epoch: 3, Accuracy on validation set: 0.4236434108527132
# Epoch: 4, Accuracy on validation set: 0.4193798449612403
# Epoch: 5, Accuracy on validation set: 0.46472868217054264
# Epoch: 6, Accuracy on validation set: 0.4689922480620155
# Epoch: 7, Accuracy on validation set: 0.48914728682170544
# Epoch: 8, Accuracy on validation set: 0.4817829457364341
# Epoch: 9, Accuracy on validation set: 0.5255813953488372
# Epoch: 10, Accuracy on validation set: 0.4910852713178295
# Epoch: 11, Accuracy on validation set: 0.5116279069767442
# Epoch: 12, Accuracy on validation set: 0.47015503875968995
# Epoch: 13, Accuracy on validation set: 0.5302325581395348
# Epoch: 14, Accuracy on validation set: 0.5321705426356589
# Epoch: 15, Accuracy on validation set: 0.5089147286821706
# Epoch: 16, Accuracy on validation set: 0.5624031007751938
# Epoch: 17, Accuracy on validation set: 0.5465116279069767
# Epoch: 18, Accuracy on validation set: 0.5569767441860465
# Epoch: 19, Accuracy on validation set: 0.48953488372093024
# Epoch: 20, Accuracy on validation set: 0.5228682170542636
# Epoch: 21, Accuracy on validation set: 0.4996124031007752
# Epoch: 22, Accuracy on validation set: 0.5344961240310078
# Epoch: 23, Accuracy on validation set: 0.5375968992248062
# Epoch: 24, Accuracy on validation set: 0.4934108527131783
# Epoch: 25, Accuracy on validation set: 0.5341085271317829
# Epoch: 26, Accuracy on validation set: 0.5790697674418605
# Epoch: 27, Accuracy on validation set: 0.560077519379845
# Epoch: 28, Accuracy on validation set: 0.5585271317829458
# Epoch: 29, Accuracy on validation set: 0.6170542635658914
# Epoch: 30, Accuracy on validation set: 0.625968992248062
# Epoch: 31, Accuracy on validation set: 0.6166666666666667
# Epoch: 32, Accuracy on validation set: 0.560077519379845
# Epoch: 33, Accuracy on validation set: 0.5589147286821705
# Epoch: 34, Accuracy on validation set: 0.5135658914728682
# Epoch: 35, Accuracy on validation set: 0.5313953488372093
# Epoch: 36, Accuracy on validation set: 0.5624031007751938
# Epoch: 37, Accuracy on validation set: 0.6131782945736434
# Epoch: 38, Accuracy on validation set: 0.5864341085271317
# Epoch: 39, Accuracy on validation set: 0.560077519379845
# Epoch: 40, Accuracy on validation set: 0.5887596899224806
# Epoch: 41, Accuracy on validation set: 0.5717054263565892
# Epoch: 42, Accuracy on validation set: 0.6108527131782946
# Epoch: 43, Accuracy on validation set: 0.6139534883720931
# Epoch: 44, Accuracy on validation set: 0.5453488372093023
# Epoch: 45, Accuracy on validation set: 0.5992248062015504
# Epoch: 46, Accuracy on validation set: 0.6275193798449612
# Epoch: 47, Accuracy on validation set: 0.5426356589147286
# Epoch: 48, Accuracy on validation set: 0.5341085271317829
# Epoch: 49, Accuracy on validation set: 0.586046511627907
# Epoch: 50, Accuracy on validation set: 0.610077519379845
# Epoch: 51, Accuracy on validation set: 0.5492248062015503
# Epoch: 52, Accuracy on validation set: 0.6023255813953489
# Epoch: 53, Accuracy on validation set: 0.5325581395348837
# Epoch: 54, Accuracy on validation set: 0.5310077519379846
# Epoch: 55, Accuracy on validation set: 0.5755813953488372
# Epoch: 56, Accuracy on validation set: 0.5325581395348837
# Epoch: 57, Accuracy on validation set: 0.5806201550387597
# Epoch: 58, Accuracy on validation set: 0.575968992248062
# Epoch: 59, Accuracy on validation set: 0.5821705426356589
# Epoch: 60, Accuracy on validation set: 0.5391472868217054
# Epoch: 61, Accuracy on validation set: 0.6108527131782946
# Epoch: 62, Accuracy on validation set: 0.6042635658914729
# Epoch: 63, Accuracy on validation set: 0.5569767441860465
# Epoch: 64, Accuracy on validation set: 0.6182170542635659
# Epoch: 65, Accuracy on validation set: 0.5941860465116279
# Epoch: 66, Accuracy on validation set: 0.6193798449612403
# Early stop
# Time: 2023-04-21T18:30:16.962545 Experiment: trainer_freqmaskLSTMdifferentiator_params_mediumsinglefatclassifier
# Running experiment for  experiments_rnn/trainer_freqmaskLSTMdifferentiator_params_mediumsinglefatclassifier_run_4
# Epoch: 1, Accuracy on validation set: 0.3492248062015504
# Epoch: 2, Accuracy on validation set: 0.4135658914728682
# Epoch: 3, Accuracy on validation set: 0.47325581395348837
# Epoch: 4, Accuracy on validation set: 0.5054263565891473
# Epoch: 5, Accuracy on validation set: 0.5124031007751938
# Epoch: 6, Accuracy on validation set: 0.5275193798449612
# Epoch: 7, Accuracy on validation set: 0.5356589147286822
# Epoch: 8, Accuracy on validation set: 0.5116279069767442
# Epoch: 9, Accuracy on validation set: 0.5604651162790698
# Epoch: 10, Accuracy on validation set: 0.5678294573643411
# Epoch: 11, Accuracy on validation set: 0.5833333333333334
# Epoch: 12, Accuracy on validation set: 0.5410852713178295
# Epoch: 13, Accuracy on validation set: 0.5875968992248062
# Epoch: 14, Accuracy on validation set: 0.6050387596899225
# Epoch: 15, Accuracy on validation set: 0.5914728682170542
# Epoch: 16, Accuracy on validation set: 0.6073643410852713
# KeyboardInterrupt
