# %%
import torch
import torchvision
import torch.nn as nn
import time
import json
import datetime
import matplotlib.pyplot as plt

# %%
# %cd
from DeepLearning.Project2.data_loading_preparation import *
# Out:
# /home/kacper

# %%
def get_generic_classifier(input_size, hidden_size, output_size):
    classifier = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(hidden_size, output_size),
    )
    return classifier
    
class LSTMSimple(nn.Module):
    def __init__(
        self,
        input_size, 
        hidden_size,
        num_layers,
        num_classes = 12,
        avgpool_dim = 32,
        classifier_size = 512,
        add_dropout=True
    ):       
        super().__init__()
        self.normalization = nn.BatchNorm1d(input_size)
        self.features = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.avgpool = nn.AdaptiveAvgPool1d(avgpool_dim)
        self.classifier = get_generic_classifier(
            hidden_size * avgpool_dim,
            classifier_size,
            num_classes
        )

    def forward(self, x):
        x = self.normalization(x)
        x = x.mT
        x, _ = self.features(x)
        x = x.mT
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def eval_accuracy(model, dataloader, reccurrent, training_device='cuda'):
    with torch.no_grad():
        model.to(training_device)
        correct = 0
        all_so_far = 0
        for inputs, labels in dataloader:
            inputs, labels = inputs.float().to(training_device), labels.float().to(training_device)
            yhat = model(inputs)
            pred = torch.argmax(yhat, dim=1)

            
            all_so_far += labels.size().numel()
            correct += torch.sum(pred.eq(labels)).item()
    return correct/all_so_far

# %%
def backup_to_ram(model):
    from copy import deepcopy
    return deepcopy(model).cpu()

class EarlyStopper:
    def __init__(self, patience = 3, backup_method=backup_to_ram):
        self.patience = patience
        self.current = 0
        
        self.backup_method = backup_method
        
        self.best_backup = None
        self.best_accuracy = 0.

    def should_continue(self, accuracy, model = None):
        if self.best_accuracy < accuracy:
            self.current = 0
            self.best_accuracy = accuracy
            if model is not None:
                self.best_backup = self.backup_method(model)
            return True
        
        self.current += 1
        
        if self.current >= self.patience:
            return False
        return True

# %%
def run_experiment(experiment_name, train_func, run, train_params=None):
    path = f"experiments_rnn/{experiment_name}_run_{run}_"
    print("Running experiment for ", path[:-1])
    
    import os
    try:
        if os.stat(path + "report.json").st_size != 0:
            print("Report exists already for " + path[:-1] + ". Skipping...")
            return
    except OSError:
        pass
    
    model, trajectory, validation_accuracy = train_func(train_params)
    
    with open(path + "report.json", "w") as f:
        json.dump(
            {
                "name": experiment_name,
                "train_params": train_params,
                "run": run,
                "best_accuracy_validation": validation_accuracy,
                "time_generated": datetime.datetime.now().isoformat(),
                "trajectory": trajectory
            },
            f
        )
    torch.save(model, path + "model.pt")

# %%
training_device = "cuda"
device = "cuda"
max_epochs = 250

def noaugLSTM(params):  
    train, test, val = load_audio_dataloaders_validation(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timeshiftLSTM(params):  
    train, test, val = load_audio_dataloaders_timeshift(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def pitchshiftLSTM(params):  
    train, test, val = load_audio_dataloaders_pitchshift(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def speedshiftLSTM(params):  
    train, test, val = load_audio_dataloaders_speedshift(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timemaskLSTM(params):  
    train, test, val = load_audio_dataloaders_timemask(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy

def freqmaskLSTM(params):  
    train, test, val = load_audio_dataloaders_freqmask(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy


def timeshiftfreqmaskLSTM(params):  
    train, test, val = load_audio_dataloaders_timeshift_freqmask(bs=128, limit_11=1.0)
    criterion_weights = torch.tensor([1.] * 11 + [0.1]).to(device)
    model = LSTMSimple(**params).to(training_device)
    criterion = torch.nn.CrossEntropyLoss(weight=criterion_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=[0.9, 0.999], eps=10e-8)
    early_stopper = EarlyStopper(patience = 20)
    trajectory = []
    model.to(training_device)

    for epoch in range(1, max_epochs+1):
        model.train()
        for x, y in train:
            optimizer.zero_grad()
            x, y = x.float().to(device), y.float().to(device)
            (yhat) = model(x)
            loss = criterion(yhat.softmax(1), y.long())
            loss.backward()
            optimizer.step()
        
        validation_accuracy = eval_accuracy(model, val, training_device)
        
        print("Epoch: {}, Accuracy on validation set: {}".format(epoch, validation_accuracy))
        
        trajectory.append({
            "epoch": epoch,
            "validation": validation_accuracy,
        })
        
        if not early_stopper.should_continue(validation_accuracy, model):
            print("Early stop")
            model = early_stopper.best_backup
            model = model.to(device)
            break

    return model, trajectory, validation_accuracy

# %%
param_grid = {
    "smallsingle": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 1,
    },
    "mediumsingle": {
        "hidden_size": 128,
        "input_size": 20,
        "num_layers": 1,
    },
    "smallsinglefatclassifier": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 1,
        "classifier_size": 4096
    },
    "smalldoublefatclassifier": {
        "hidden_size": 64,
        "input_size": 20,
        "num_layers": 2,
        "classifier_size": 4096
    },
    "mediumsinglefatclassifier": {
        "hidden_size": 128,
        "input_size": 20,
        "num_layers": 1,
        "classifier_size": 4096
    },
}


experiment_list = [
    (
        f"trainer_{trainer.__name__}_params_{param_name}", 
        trainer,
        str(run),
        param
    )
    for run in range(1, 11) 
    for trainer in [noaugLSTM, pitchshiftLSTM, speedshiftLSTM, timeshiftLSTM, timemaskLSTM, freqmaskLSTM, timeshiftfreqmaskLSTM]
    for param_name, param in param_grid.items()
]

# %%
len(experiment_list)
# Out:
# 350

# %%
for experiment in experiment_list:
    print(
        "Time:", datetime.datetime.now().isoformat(),
        "Experiment:", experiment[0]
    )
    try:
        run_experiment(*experiment)
    except Exception as e:
        print("Error occured, skipping...\n", repr(e))
# Out:
# Time: 2023-04-20T18:28:28.847616 Experiment: trainer_noaugLSTM_params_smallsingle
# Running experiment for  experiments_rnn/trainer_noaugLSTM_params_smallsingle_run_1
# Epoch: 1, Accuracy on validation set: 0.44669901485075725
# Epoch: 2, Accuracy on validation set: 0.49360388178209086
# Epoch: 3, Accuracy on validation set: 0.49301573298044404
# Epoch: 4, Accuracy on validation set: 0.4953683281870313
# Epoch: 5, Accuracy on validation set: 0.504925746213792
# Epoch: 6, Accuracy on validation set: 0.5493309807381267
# Epoch: 7, Accuracy on validation set: 0.5255109542714307
# Epoch: 8, Accuracy on validation set: 0.5991765916776944
# Epoch: 9, Accuracy on validation set: 0.5825613880311719
# Epoch: 10, Accuracy on validation set: 0.5255109542714307
# Epoch: 11, Accuracy on validation set: 0.5577121011615939
# Epoch: 12, Accuracy on validation set: 0.45831495368328184
# Epoch: 13, Accuracy on validation set: 0.5759447140126452
# Epoch: 14, Accuracy on validation set: 0.60138214968387
# Epoch: 15, Accuracy on validation set: 0.5662402587854727
# Epoch: 16, Accuracy on validation set: 0.6219673577415086
# Epoch: 17, Accuracy on validation set: 0.5408028231142479
# Epoch: 18, Accuracy on validation set: 0.564622849580944
# Epoch: 19, Accuracy on validation set: 0.623290692545214
# Epoch: 20, Accuracy on validation set: 0.6044699308925158
# Epoch: 21, Accuracy on validation set: 0.55565358035583
# Epoch: 22, Accuracy on validation set: 0.595941773268637
# Epoch: 23, Accuracy on validation set: 0.6349066313777386
# Epoch: 24, Accuracy on validation set: 0.6138803117188649
# Epoch: 25, Accuracy on validation set: 0.5325687398911925
# Epoch: 26, Accuracy on validation set: 0.6185855021320394
# Epoch: 27, Accuracy on validation set: 0.503455374209675
# Epoch: 28, Accuracy on validation set: 0.533303925893251
# Epoch: 29, Accuracy on validation set: 0.5197765034553742
# Epoch: 30, Accuracy on validation set: 0.5562417291574768
# Epoch: 31, Accuracy on validation set: 0.5875606528451698
# Epoch: 32, Accuracy on validation set: 0.5233053962652551
# Epoch: 33, Accuracy on validation set: 0.5518306131451257
# Epoch: 34, Accuracy on validation set: 0.5649169239817674
# Epoch: 35, Accuracy on validation set: 0.5852080576385825
# Epoch: 36, Accuracy on validation set: 0.6325540361711512
# Epoch: 37, Accuracy on validation set: 0.603881782090869
# Epoch: 38, Accuracy on validation set: 0.5062490810174974
# Epoch: 39, Accuracy on validation set: 0.6227025437435671
# Epoch: 40, Accuracy on validation set: 0.5350683722981915
# Epoch: 41, Accuracy on validation set: 0.48198794294956626
# Epoch: 42, Accuracy on validation set: 0.5856491692398177
# Epoch: 43, Accuracy on validation set: 0.5816791648287016
# Early stop
# Time: 2023-04-20T18:36:14.600647 Experiment: trainer_noaugLSTM_params_mediumsingle
# Running experiment for  experiments_rnn/trainer_noaugLSTM_params_mediumsingle_run_1
# Epoch: 1, Accuracy on validation set: 0.4478753124540509
# Epoch: 2, Accuracy on validation set: 0.5122776062343773
# Epoch: 3, Accuracy on validation set: 0.45963828848698723
# Epoch: 4, Accuracy on validation set: 0.5147772386413763
# Epoch: 5, Accuracy on validation set: 0.5402146743126011
# Epoch: 6, Accuracy on validation set: 0.5061020438170857
# Epoch: 7, Accuracy on validation set: 0.47640052933392146
# Epoch: 8, Accuracy on validation set: 0.5024261138067931
# Epoch: 9, Accuracy on validation set: 0.528304661079253
